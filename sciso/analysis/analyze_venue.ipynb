# %%
import json
from tqdm import tqdm
from pymongo import MongoClient

db = MongoClient("localhost", 27017).get_database("sciso-2024")
pub_refs = db.get_collection("pub_refs")

with open("venues.json", "r") as f:
    venue_info = json.load(f)


def normalize_venue(doc):
    if raw_venue := doc.get("metadata", {}).get("venue", None):
        if type(raw_venue) == dict:
            if raw_venue.get("name", None):
                updated_venue = venue_info.get(raw_venue.get("name"), None)
                if updated_venue:
                    if type(updated_venue) == dict:
                        doc["metadata"]["normalized_venue"] = updated_venue.get("name", None)
                    else:
                        doc["metadata"]["normalized_venue"] = updated_venue
                else:
                    doc["metadata"]["normalized_venue"] = raw_venue.get("name", None)
            else:
                print(f"Missing name for venue {raw_venue}")
        elif type(raw_venue) == str:
            if raw_venue in venue_info:
                norm_venue = venue_info[raw_venue]
                if type(norm_venue) == dict:
                    norm_venue = norm_venue.get("name", None)
                doc["metadata"]["normalized_venue"] = norm_venue
            else:
                print(f"Missing venue {raw_venue}")
                doc["metadata"]["normalized_venue"] = raw_venue
        else:
            print(f"Unknown type for venue {raw_venue}")
    else:
        print(f"Missing venue for {doc['_id']}")
    return doc


def update_venue():
    cursor = pub_refs.find({"metadata.venue": {"$exists": True, "$ne": None}})
    for doc in tqdm(
        cursor,
        total=pub_refs.count_documents(
            {"metadata.venue": {"$exists": True, "$ne": None}}
        ),
    ):
        pub_refs.update_one({"_id": doc["_id"]}, {"$set": normalize_venue(doc)})


# be careful before running this!!!!! remember to run resolve_conflicts.ipynb after running this!!!!!
# update_venue()
# Out:
# 100%|██████████| 13281/13281 [00:05<00:00, 2290.25it/s]

# %%
def output_pub_refs():
    with open("pub_refs_24_nor.jsonl", "w") as f:
        cursor = pub_refs.find({})
        for doc in tqdm(cursor, total=pub_refs.count_documents({})):
            f.write(json.dumps(doc, default=str, separators=("," ":")) + "\n")
# output_pub_refs()
# Out:
# 100%|██████████| 14914/14914 [00:01<00:00, 7756.15it/s]

# %%
import pandas as pd
pubrefs = pd.read_json("../../sciso.jsonl", lines=True)
pubrefs = pubrefs[["PostId", "metadata", "Url", "History", "LinkType", "AddedAt", "AddedBy", "RevisionId", "Source"]]
pubrefs.head()
# Out:
#    PostId  \
# 0   37933
# 1  125285
# 2   80736
# 3  133356
# 4   25248
#
#                                                                                               metadata  \
# 0  {'title': 'Asynchronous completion token', 'authors': [{'name': 'Irfan Pyarali', 'id': '1840209'...
# 1  {'title': 'Impact of high-intensity negotiated-style interruptions on end-user debugging', 'venu...
# 2  {'title': 'A note on the genuine Sieve of Eratosthenes', 'authors': [{'name': 'M. Nykänen', 'id'...
# 3  {'title': 'Writing Hygienic Macros in Scheme with Syntax-Case', 'authors': [{'name': 'Kent Dybvi...
# 4  {'title': 'A consensus glossary of temporal database concepts', 'authors': [{'name': 'C. Dyreson...
#
#                                                               Url  History  \
# 0                   http://www.cse.wustl.edu/~schmidt/PDF/ACT.pdf        2
# 1   ftp://ftp.cs.orst.edu/pub/burnett/jvlc-interruptions-2006.pdf        2
# 2              http://www.cs.hmc.edu/~oneill/papers/Sieve-JFP.pdf        2
# 3       http://www.cs.uml.edu/~giam/91.531/Textbooks/RKDybvig.pdf        2
# 4  http://www.cs.arizona.edu/~rts/pubs/SIGMODRecordMarch94p52.pdf        2
#
#   LinkType                  AddedAt  AddedBy  RevisionId Source
# 0      pdf  2008-09-01T13:23:18.830     2010       52547    pdf
# 1      pdf  2008-09-24T03:37:32.107     5113      178094    pdf
# 2      pdf  2008-09-17T07:15:11.747     9632      114305    pdf
# 3      pdf  2008-09-25T13:34:28.060     7851      190988    pdf
# 4      pdf  2008-08-24T18:11:02.603     2010       33333    pdf

# %%
metadata = pd.DataFrame(list(pubrefs["metadata"]))
metadata = metadata[["title", "normalized_venue", "year", "citation_count", "authors", "type", "open_access", "external_ids", "concepts"]].join(pubrefs["PostId"])
metadata["year"] = metadata["year"].astype("Int64")
metadata.head()
# Out:
#                                                                            title  \
# 0                                                  Asynchronous completion token
# 1  Impact of high-intensity negotiated-style interruptions on end-user debugging
# 2                                    A note on the genuine Sieve of Eratosthenes
# 3                             Writing Hygienic Macros in Scheme with Syntax-Case
# 4                             A consensus glossary of temporal database concepts
#
#                                   normalized_venue  year  citation_count  \
# 0  Addison wesley longman publishing co inc ebooks  1997             8.0
# 1        Journal of visual languages and computing  2005             4.0
# 2                Journal of functional programming  2008            44.0
# 3                                              NaN  1992            35.0
# 4                            ACM SIGMOD Conference  1994           495.0
#
#                                                                                                authors  \
# 0  [{'name': 'Irfan Pyarali', 'id': '1840209'}, {'name': 'Timothy H. Harrison', 'id': '2079983'}, {...
# 1                                                                                                  NaN
# 2                                                            [{'name': 'M. Nykänen', 'id': '1890836'}]
# 3                                                     [{'name': 'Kent Dybvigdyb', 'id': '2262888616'}]
# 4  [{'name': 'C. Dyreson', 'id': '1710939'}, {'name': 'F. Grandi', 'id': '143732420'}, {'name': 'W....
#
#                                 type open_access  \
# 0                             [book]       False
# 1                  [journal-article]       False
# 2  [JournalArticle, journal-article]        True
# 3                  [journal-article]       False
# 4                  [journal-article]        True
#
#                                                                                           external_ids  \
# 0  {'s2': '44bb7b1bada2a777a131af91a1fbacc7e0bda541', 'mag': '1577953154', 'corpusid': 267916118, '...
# 1                                                     {'openalex': 'https://openalex.org/W1987666248'}
# 2  {'s2': 'e6e9eb7f5c4f9d935d2b92b9baa5e293995fef81', 'mag': '2168056765', 'dblp': 'journals/jfp/Ny...
# 3  {'s2': '8705776b20156fe235a7dc5a4fd0a6ff0fcb486a', 'mag': '2134717046', 'corpusid': 7608716, 'op...
# 4  {'s2': '28e57aeb8a9e8cd798c1ee59644a22568f0d666e', 'mag': '1971864291', 'doi': '10.1145/181550.1...
#
#                                                                                               concepts  \
# 0  [{'id': 'https://openalex.org/C41008148', 'display_name': 'computer science', 'level': 0, 'score...
# 1  [{'id': 'https://openalex.org/C41008148', 'display_name': 'computer science', 'level': 0, 'score...
# 2  [{'id': 'https://openalex.org/C41008148', 'display_name': 'computer science', 'level': 0, 'score...
# 3  [{'id': 'https://openalex.org/C41008148', 'display_name': 'computer science', 'level': 0, 'score...
# 4  [{'id': 'https://openalex.org/C41008148', 'display_name': 'computer science', 'level': 0, 'score...
#
#    PostId
# 0   37933
# 1  125285
# 2   80736
# 3  133356
# 4   25248

# %%
venue_grouped = metadata.groupby("normalized_venue").size().reset_index(name="count")
venue_grouped = venue_grouped.sort_values(by="count", ascending=False)
venue_grouped.to_json("venue_grouped.json", orient="records")
venue_grouped.head()
# Out:
#                                           normalized_venue  count
# 3467                                             arXiv.org   1831
# 2616                 Neural Information Processing Systems    629
# 583                Computer Vision and Pattern Recognition    581
# 1659  International Conference on Learning Representations    562
# 1660          International Conference on Machine Learning    418

# %%
metadata_grouped = metadata.groupby("title").agg(
    {
        "normalized_venue": lambda x: set(x),
        "year": "min",
        "citation_count": "max",
        "open_access": "any",
        "PostId": lambda x: set(x),
    }
).reset_index()
metadata_grouped
# Out:
#                                                                                                      title  \
# 0                                                   Neural Network Methods for Natural Language Processing
# 1              "Low-Resource" Text Classification: A Parameter-Free Classification Method with Compressors
# 2                                         #ifdef Considered Harmful, or Portability Experience with C News
# 3                                                  $2.00 Gas! Studying the Effects of a Gas Tax Moratorium
# 4      $\mu $ RNG: A 300–950 mV, 323 Gbps/W All-Digital Full-Entropy True Random Number Generator in 14...
# ...                                                                                                    ...
# 13282   “One Against One” or “One Against All”: Which One is Better for Handwriting Recognition with SVMs?
# 13283  “Search, Show Context, Expand on Demand”: Supporting Large Graph Exploration with Degree-of-Inte...
# 13284          “Should This Loan be Approved or Denied?”: A Large Dataset with Class Assignment Guidelines
# 13285                                               “We Are Here to Help”Who Opens the Gate for Surgeries?
# 13286                              “Why Should I Trust You?”: Explaining the Predictions of Any Classifier
#
#                                                                 normalized_venue  \
# 0                                                    {Computational Linguistics}
# 1              {Annual Meeting of the Association for Computational Linguistics}
# 2                                                                {Usenix summer}
# 3                                                  {Journal of Public Economics}
# 4                                         {IEEE Journal of Solid-State Circuits}
# ...                                                                          ...
# 13282    {nan, International Conference on Frontiers in Handwriting Recognition}
# 13283                 {IEEE Transactions on Visualization and Computer Graphics}
# 13284                                          {Journal of statistics education}
# 13285                                        {Tsq transgender studies quarterly}
# 13286  {North American Chapter of the Association for Computational Linguistics}
#
#        year  citation_count  open_access  \
# 0      2017           549.0         True
# 1      2023            52.0         True
# 2      1992           246.0        False
# 3      2008           162.0         True
# 4      2016            83.0        False
# ...     ...             ...          ...
# 13282  2006           272.0        False
# 13283  2009           257.0        False
# 13284  2018            33.0         True
# 13285  2018            10.0        False
# 13286  2016         15035.0         True
#
#                                                   PostId
# 0                                             {48445189}
# 1                                             {76724158}
# 2                   {489434, 8012461, 21097319, 9294487}
# 3                                             {75879031}
# 4                                             {61554191}
# ...                                                  ...
# 13282                     {16728386, 16252899, 16793390}
# 13283                                         {21893401}
# 13284                                         {64403934}
# 13285             {5017208, 58591979, 14537012, 5151693}
# 13286  {49353040, 49937523, 44470613, 52392344, 7017439}
#
# [13287 rows x 6 columns]

# %%
pd.set_option("display.max_colwidth", 100)
conflicted_venue_idx = metadata_grouped["normalized_venue"].apply(len) > 1
metadata_grouped[conflicted_venue_idx]
# Out:
#                                                                                                      title  \
# 77                         A Bootstrap Evaluation of the Effect of Data Splitting on Financial Time Series
# 186                                 A Decorated Parallel Coordinate Plot for Categorical Longitudinal Data
# 655                                                                 A Survey of Text Similarity Approaches
# 729                                                   A Unified Approach to Interpreting Model Predictions
# 871                                                             A fast triangle-triangle intersection test
# ...                                                                                                    ...
# 12057              The normal law under linear restrictions: simulation and estimation via minimax tilting
# 12079                                                             The quickhull algorithm for convex hulls
# 12673                       Using Evolutionary Testing to Find Test Scenarios for Hard to Reproduce Faults
# 12973  What matters in differences between life trajectories: a comparative review of sequence dissimil...
# 13282   “One Against One” or “One Against All”: Which One is Better for Handwriting Recognition with SVMs?
#
#                                                                                           normalized_venue  \
# 77                                      {Ieee trans neural networks, IEEE Transactions on Neural Networks}
# 186                                                     {American Statistician, The american statistician}
# 655                                                  {International journal of computer applications, nan}
# 729                                                     {arXiv.org, Neural Information Processing Systems}
# 871                                    {Journal of graphics gpu and game tools, Journal of graphics tools}
# ...                                                                                                    ...
# 12057  {Journal of the royal statistical society series b, Journal of the royal statistical society ser...
# 12079                                                    {Toms, ACM Transactions on Mathematical Software}
# 12673  {International Conference on Software Testing, Verification and Validation Workshops, Internatio...
# 12973        {Journal of the royal statistical society series a, Journal of the royal statistical society}
# 13282                              {nan, International Conference on Frontiers in Handwriting Recognition}
#
#        year  citation_count  open_access  \
# 77     1998           106.0         True
# 186    2014            18.0        False
# 655    2013           851.0         True
# 729    2017         17636.0         True
# 871    1997           438.0        False
# ...     ...             ...          ...
# 12057  2016           221.0         True
# 12079  1996          5269.0         True
# 12673  2010             2.0        False
# 12973  2015           357.0         True
# 13282  2006           272.0        False
#
#                                                                                                     PostId
# 77                                                                                              {25067048}
# 186                                                                                   {75517617, 28968342}
# 655                                                                                   {44595712, 42657333}
# 729    {62398529, 69905537, 72096547, 66844388, 60987558, 76481990, 75090662, 72957961, 67488811, 58203...
# 871                                                       {35400896, 1496260, 29563443, 1496345, 36473309}
# ...                                                                                                    ...
# 12057                                                                                 {68814235, 51218340}
# 12079                                                             {75396912, 43965579, 66151164, 12333877}
# 12673                                                                                           {25322117}
# 12973                                                                       {75517617, 77837858, 53281018}
# 13282                                                                       {16728386, 16252899, 16793390}
#
# [81 rows x 6 columns]

# %%
len(metadata_grouped)
# Out:
# 13287

# %%
metadata_grouped["normalized_venue"] = metadata_grouped["normalized_venue"].apply(
    lambda x: list(x)[0] if len(x) == 1 else x
)
metadata_grouped["reference_count"] = metadata_grouped["PostId"].apply(len)
metadata_grouped.sort_values("reference_count", ascending=False).head(11)
# Out:
#                                                                                                     title  \
# 2404         Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift
# 2196                                                                            Attention is All you Need
# 12504                                     U-Net: Convolutional Networks for Biomedical Image Segmentation
# 6357   IEEE Standard for SystemVerilog--Unified Hardware Design, Specification, and Verification Language
# 2355                     BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# 4349                                    Dropout: a simple way to prevent neural networks from overfitting
# 9661                                                                    Purely Functional Data Structures
# 3846                                                         Deep Residual Learning for Image Recognition
# 12571                           Understanding the difficulty of training deep feedforward neural networks
# 1393                                                           Adam: A Method for Stochastic Optimization
# 12641                                                                                            Untitled
#
#                                                                              normalized_venue  \
# 2404                                             International Conference on Machine Learning
# 2196                                                    Neural Information Processing Systems
# 12504  International Conference on Medical Image Computing and Computer-Assisted Intervention
# 6357                                                                                      NaN
# 2355                  North American Chapter of the Association for Computational Linguistics
# 4349                                                     Journal of machine learning research
# 9661                                                                                      NaN
# 3846                                                  Computer Vision and Pattern Recognition
# 12571                      International Conference on Artificial Intelligence and Statistics
# 1393                                     International Conference on Learning Representations
# 12641                                                                                     NaN
#
#        year  citation_count  open_access  \
# 2404   2015         41504.0         True
# 2196   2017        110977.0         True
# 12504  2015         68758.0         True
# 6357   2017            41.0        False
# 2355   2018         84697.0         True
# 4349   2014         38062.0        False
# 9661   1998           598.0        False
# 3846   2015        177579.0         True
# 12571  2010         16786.0        False
# 1393   2014        142334.0         True
# 12641  2024            16.0        False
#
#                                                                                                     PostId  \
# 2404   {44475009, 69508740, 46181636, 40314502, 41416583, 39258253, 53335053, 58256783, 45731612, 63020...
# 2196   {62575360, 59377538, 62177796, 56930821, 63178631, 63298183, 71400202, 78645642, 69129741, 65343...
# 12504  {65635714, 68121220, 71277061, 59237001, 65604874, 40640906, 65921292, 64972431, 56764048, 53963...
# 6357   {77293184, 77502338, 69790851, 64085508, 77344521, 57198731, 62908941, 67739151, 77528852, 76447...
# 2355   {64588418, 78201090, 71965576, 56129165, 56828558, 55114128, 55982099, 54773912, 55066010, 60493...
# 4349   {41311232, 44131458, 44036610, 37210500, 54170758, 42696199, 44109320, 44224010, 50843787, 57909...
# 9661   {20205191, 5573640, 1602574, 8773006, 528528, 12393104, 13236370, 8237847, 2279320, 2223258, 227...
# 3846   {62024327, 65604874, 46904460, 68258188, 61841938, 58213909, 50390549, 68845078, 54868504, 43355...
# 12571  {45521025, 45380994, 37372682, 42564875, 47987212, 72603152, 34642719, 43489697, 41565985, 46360...
# 1393   {60872321, 41450882, 49977348, 52474500, 60667655, 53929352, 56440329, 56115600, 76281366, 39765...
# 12641  {60001408, 17846016, 47535748, 47935492, 73923076, 13833338, 22131080, 25260426, 6033303, 160120...
#
#        reference_count
# 2404                67
# 2196                62
# 12504               57
# 6357                57
# 2355                51
# 4349                46
# 9661                45
# 3846                43
# 12571               42
# 1393                41
# 12641               38

# %%
metadata_grouped[
    metadata_grouped["title"]
    == "MapReduce: simplified data processing on large clusters"
]
# Out:
#                                                         title  \
# 7591  MapReduce: simplified data processing on large clusters
#
#                        normalized_venue  year  citation_count  open_access  \
# 7591  {Cacm, Communications of the ACM}  2004         25616.0         True
#
#                                        PostId  reference_count
# 7591  {2818613, 26985557, 12901694, 12896855}                4

# %%
metadata_grouped[metadata_grouped["title"] == "A Future-Adaptable Password Scheme"]
# Out:
#                                   title                    normalized_venue  \
# 266  A Future-Adaptable Password Scheme  USENIX Annual Technical Conference
#
#      year  citation_count  open_access  \
# 266  <NA>           212.0        False
#
#                                                                                                   PostId  \
# 266  {67114272, 30029026, 36080835, 1645190, 53692391, 11101384, 4984044, 39875161, 4772058, 33912028...
#
#      reference_count
# 266               11

# %%
metadata_grouped.sort_values("citation_count", ascending=False).head(10)
# Out:
#                                                                                                      title  \
# 9631                                                    Protein measurement with the Folin phenol reagent.
# 9011                                                     PROTEIN MEASUREMENT WITH THE FOLIN PHENOL REAGENT
# 3846                                                          Deep Residual Learning for Image Recognition
# 1393                                                            Adam: A Method for Stochastic Optimization
# 6464                                       ImageNet classification with deep convolutional neural networks
# 2196                                                                             Attention is All you Need
# 12798                                   Very Deep Convolutional Networks for Large-Scale Image Recognition
# 9838                                                                                        Random Forests
# 12044  The moderator-mediator variable distinction in social psychological research: conceptual, strate...
# 2401                                                                    Basic local alignment search tool.
#
#                                                          normalized_venue  \
# 9631                                      Journal of Biological Chemistry
# 9011                                      Journal of Biological Chemistry
# 3846                              Computer Vision and Pattern Recognition
# 1393                 International Conference on Learning Representations
# 6464   {Neural Information Processing Systems, Communications of the ACM}
# 2196                                Neural Information Processing Systems
# 12798                International Conference on Learning Representations
# 9838                         {Springer ebooks, Machine-mediated learning}
# 12044                        Journal of Personality and Social Psychology
# 2401                                         Journal of Molecular Biology
#
#        year  citation_count  open_access  \
# 9631   1951        318671.0         True
# 9011   1951        318671.0         True
# 3846   2015        177579.0         True
# 1393   2014        142334.0         True
# 6464   2012        113943.0         True
# 2196   2017        110977.0         True
# 12798  2014         94664.0         True
# 9838   2001         91631.0         True
# 12044  1986         87911.0         True
# 2401   1990         87795.0         True
#
#                                                                                                     PostId  \
# 9631                                                                        {55592324, 14608444, 58489165}
# 9011                                                                                            {24634890}
# 3846   {62024327, 65604874, 46904460, 68258188, 61841938, 58213909, 50390549, 68845078, 54868504, 43355...
# 1393   {60872321, 41450882, 49977348, 52474500, 60667655, 53929352, 56440329, 56115600, 76281366, 39765...
# 6464   {61167744, 65405953, 50193801, 40060949, 41841173, 51015834, 28232235, 48493868, 76746931, 15578...
# 2196   {62575360, 59377538, 62177796, 56930821, 63178631, 63298183, 71400202, 78645642, 69129741, 65343...
# 12798  {54997632, 61321247, 60812966, 65612711, 51854502, 54295849, 78408109, 62370995, 39095735, 42434...
# 9838                                                    {70360996, 11501381, 65530093, 24663120, 58937426}
# 12044                                                                                            {1219480}
# 2401                                                                                             {1432570}
#
#        reference_count
# 9631                 3
# 9011                 1
# 3846                43
# 1393                41
# 6464                25
# 2196                62
# 12798               26
# 9838                 5
# 12044                1
# 2401                 1

# %%
def describe_stats(x):
    num_list = []
    for i in x:
        try:
            num_list.append(int(i))
        except:
            pass
    return (
        pd.Series(num_list)
        .describe(include=["mean", "std", "min", "25%", "50%", "75%", "max"])
        .to_dict()
    )


venue_citation_year = metadata_grouped.groupby("normalized_venue").agg(
    {"citation_count": list, "year": list}
)
venue_citation_year["count"] = metadata_grouped.groupby("normalized_venue").size()
venue_citation_year = venue_citation_year.sort_values(
    "count", ascending=False
).reset_index()
venue_citation_year["citation_stat"] = venue_citation_year["citation_count"].apply(
    describe_stats
)
venue_citation_year["year_stat"] = venue_citation_year["year"].apply(describe_stats)
venue_citation_year[
    ["normalized_venue", "count", "citation_stat", "year_stat"]
].to_json("venue_citation_year_stat.json", orient="records")
venue_citation_year.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 15
#       7             pass
#       8     return (
#       9         pd.Series(num_list)
#      10         .describe(include=["mean", "std", "min", "25%", "50%", "75%", "max"])
#      11         .to_dict()
#      12     )
# ---> 15 venue_citation_year = metadata_grouped.groupby("normalized_venue").agg(
#      16     {"citation_count": list, "year": list}
#      17 )
#      18 venue_citation_year["count"] = metadata_grouped.groupby("normalized_venue").size()
#      19 venue_citation_year = venue_citation_year.sort_values(
#      20     "count", ascending=False
#      21 ).reset_index()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1269, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1266 func = maybe_mangle_lambdas(func)
#    1268 op = GroupByApply(self, func, args, kwargs)
# -> 1269 result = op.agg()
#    1270 if not is_dict_like(func) and result is not None:
#    1271     return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:163, in Apply.agg(self)
#     160     return self.apply_str()
#     162 if is_dict_like(arg):
# --> 163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
#     166     return self.agg_list_like()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:420, in Apply.agg_dict_like(self)
#     417         results = {key: colg.agg(how) for key, how in arg.items()}
#     418     else:
#     419         # key used for column selection and output
# --> 420         results = {
#     421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#     425 keys = list(arg.keys())
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:421, in <dictcomp>(.0)
#     417         results = {key: colg.agg(how) for key, how in arg.items()}
#     418     else:
#     419         # key used for column selection and output
#     420         results = {
# --> 421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#     425 keys = list(arg.keys())
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:252, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     249 if cyfunc and not args and not kwargs:
#     250     return getattr(self, cyfunc)()
# --> 252 if self.ngroups == 0:
#     253     # e.g. test_evaluate_with_empty_groups without any groups to
#     254     #  iterate over, we have no output on which to do dtype
#     255     #  inference. We default to using the existing dtype.
#     256     #  xref GH#51445
#     257     obj = self._obj_with_exclusions
#     258     return self.obj._constructor(
#     259         [],
#     260         name=self.obj.name,
#     261         index=self.grouper.result_index,
#     262         dtype=obj.dtype,
#     263     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:653, in BaseGroupBy.ngroups(self)
#     650 @final
#     651 @property
#     652 def ngroups(self) -> int:
# --> 653     return self.grouper.ngroups
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:902, in BaseGrouper.ngroups(self)
#     899 @final
#     900 @cache_readonly
#     901 def ngroups(self) -> int:
# --> 902     return len(self.result_index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:913, in BaseGrouper.result_index(self)
#     910 @cache_readonly
#     911 def result_index(self) -> Index:
#     912     if len(self.groupings) == 1:
# --> 913         return self.groupings[0].result_index.rename(self.names[0])
#     915     codes = self.reconstructed_codes
#     916     levels = [ping.result_index for ping in self.groupings]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:698, in Grouping.result_index(self)
#     696     # set_categories is dynamically added
#     697     return group_idx.set_categories(cats)  # type: ignore[attr-defined]
# --> 698 return self.group_index
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:702, in Grouping.group_index(self)
#     700 @cache_readonly
#     701 def group_index(self) -> Index:
# --> 702     codes, uniques = self._codes_and_uniques
#     703     if not self._dropna and self._passed_categorical:
#     704         assert isinstance(uniques, Categorical)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:780, in Grouping._codes_and_uniques(self)
#     775     uniques = self._uniques
#     776 else:
#     777     # GH35667, replace dropna=False with use_na_sentinel=False
#     778     # error: Incompatible types in assignment (expression has type "Union[
#     779     # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 780     codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     781         self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     782     )
#     783 return codes, uniques
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:780, in factorize(values, sort, use_na_sentinel, size_hint)
#     777             # Don't modify (potentially user-provided) array
#     778             values = np.where(null_mask, na_value, values)
# --> 780     codes, uniques = factorize_array(
#     781         values,
#     782         use_na_sentinel=use_na_sentinel,
#     783         size_hint=size_hint,
#     784     )
#     786 if sort and len(uniques) > 0:
#     787     uniques, codes = safe_sort(
#     788         uniques,
#     789         codes,
#    (...)
#     792         verify=False,
#     793     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:581, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     578 hash_klass, values = _get_hashtable_algo(values)
#     580 table = hash_klass(size_hint or len(values))
# --> 581 uniques, codes = table.factorize(
#     582     values,
#     583     na_sentinel=-1,
#     584     na_value=na_value,
#     585     mask=mask,
#     586     ignore_na=use_na_sentinel,
#     587 )
#     589 # re-cast e.g. i8->dt64/td64, uint8->bool
#     590 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:7280, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:7194, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'set'

# %%
swarm_data = []
for idx, row in venue_citation_year.iterrows():
    swarm_data.append({
        "id": row["normalized_venue"],
        "group": "",
        "num_ref": row["count"],
        "h5i": "",
    })
    if idx == 100:
        break
json.dump(swarm_data, open("venue_swarm.json", "w"), indent=0)
