# %%
from pymongo import MongoClient

db = MongoClient('localhost', 27017).get_database("sciso-2024")
pub_refs = db.get_collection("pub_refs")

# %%
import json
from tqdm import tqdm


venue_info = {}
cursor = pub_refs.find({"metadata.venue": {"$exists": True, "$ne": None}})

for doc in tqdm(
    cursor,
    total=pub_refs.count_documents({"metadata.venue": {"$exists": True, "$ne": None}}),
):
    venue = doc["metadata"]["venue"]
    if type(venue) == dict:
        if venue["name"] not in venue_info:
            venue_info[venue["name"]] = venue
        elif type(venue_info[venue["name"]]) == str:
            venue_info[venue["name"]] = venue
        for alias in venue.get("alternate_names", []):
            if alias not in venue_info:
                venue_info[alias] = venue
            elif type(venue_info[alias]) == str:
                venue_info[alias] = venue
    elif type(venue) == str:
        if venue not in venue_info:
            venue_info[venue] = venue

print("Found {} venues".format(len(venue_info)))
with open("venue_info.json", "w") as f:
    json.dump(venue_info, f, indent=2)
# Out:
#   0%|          | 0/13281 [00:00<?, ?it/s]
# 100%|██████████| 13281/13281 [00:00<00:00, 14308.77it/s]
# Found 7279 venues

# %%
import re
import nltk
import number_parser

nltk.download("stopwords")
nltk.download("punkt")
stop_words = set(nltk.corpus.stopwords.words("english"))
stop_words.update(
    [
        "proceedings",
        "workshop",
        # "conference",
        # "international",
        # "symposium",
        # "journal",
        # "ieee",
        # "usenix",
        # "acm",
        # "association",
        "th",
        "st",
        "nd",
        "rd",
        "volume",
    ]
)
lemmatizer = nltk.stem.WordNetLemmatizer()


def clean_venue_name(venue: str):
    venue = number_parser.parse(venue)
    venue = (
        venue.replace(".", "")
        .replace("&", "and")
        .replace("'", "")
        .replace("/", " ")
        .replace("-", " ")
        .replace(",", "")
        .lower()
    )
    venue = re.sub("\\d+", "", venue)
    venue = re.sub("\\(.+?\\)", "", venue)
    venue_parts = venue.split(":", 1)
    if len(venue_parts) > 1:
        venue = (
            venue_parts[0]
            if len(venue_parts[0]) > len(venue_parts[1])
            else venue_parts[1]
        )
    tokens = nltk.word_tokenize(venue)
    return " ".join([lemmatizer.lemmatize(t) for t in tokens if t not in stop_words])


clean_venue_name("Information Hiding and Multimedia Security Workshop")
# Out:
# [nltk_data] Downloading package stopwords to /home/ruh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ruh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 'information hiding multimedia security'

# %%
import pandas as pd
valid_venues = {k: v for k, v in venue_info.items() if type(v) == dict}
valid_venues = pd.DataFrame.from_dict(valid_venues, orient="index").reset_index().rename(columns={"index": "raw_name"})
valid_venues["clean_name"] = valid_venues["raw_name"].apply(clean_venue_name)
valid_venues[valid_venues["raw_name"] == "International Conference on Image Processing"]
# Out:
#                                          raw_name  \
# 245  International Conference on Image Processing
#
#                                        id  \
# 245  b6369c33-5d70-463c-8e82-95a54efa3cc8
#
#                                                   name        type  \
# 245  International Conference on Information Photonics  conference
#
#                                        alternate_names issn  url  \
# 245  [Int Conf Image Process, ICIP, Int Conf Inf Ph...  NaN  NaN
#
#     alternate_urls alternate_issns                                 clean_name
# 245            NaN             NaN  international conference image processing

# %%
pd.set_option("display.max_colwidth", None)
same_cleaned_same = valid_venues.groupby("clean_name").agg({"id": lambda x: set(x), "raw_name": lambda x: set(x)})
same_cleaned_same[same_cleaned_same["id"].apply(len) > 1]
# Out:
#                                                                                                                            id  \
# clean_name
# cc                                               {73f7fe95-b68b-468f-b7ba-3013ca879e50, 41c21288-abea-4a71-98f6-5722d33e9edc}
# ci                                               {03e270f3-9983-44e1-9d91-754044085687, bce97c16-ce21-4e56-ab0e-0060085c0d85}
# ecosystem                                        {72cc6474-a775-4c22-823f-3684c7ef79bf, 1874d943-7e14-460b-a52f-895ceacad37c}
# icit                                             {62ece4be-f643-40a5-af47-abedd995a7cf, 6c1a00cb-4b59-44d6-a887-bfd7c5b3768f}
# international conference data engineering        {f4d9ff4f-5eeb-4aaa-a916-8246dda89fad, 764e3630-ddac-4c21-af4b-9d32ffef082e}
# international conference information technology  {e4272e2a-186f-4774-aedc-5a095c25990b, 67128bf0-cf99-46bd-8915-1d9a05820d0a}
# international conference parallel processing     {29df4b17-9a16-4a4c-94a6-002f52e628b4, 29d9d54d-04bd-4927-ba16-24662f2ac3da}
# journal experimental psychology                  {ba388b36-981e-4c1b-8048-464cdaa9c9fc, 227ccdaf-ba32-464f-8d97-064c05b56437}
# n                                                {71826259-dbc2-44dc-9ffa-abf8abd1514e, de542ef7-754d-4bd9-a2dd-47897b7cd339}
# sc                                               {048c4e4e-ad38-42be-8e06-4486715e41e0, 7ed86435-f510-45fe-b582-c212782023aa}
#
#                                                                                                                                                                                                                           raw_name
# clean_name
# cc                                                                                                                                                                                                                  {CcS, CC, CCS}
# ci                                                                                                                                                                                                                       {CIS, CI}
# ecosystem                                                                                                                                                                                              {One Ecosystem, Ecosystems}
# icit                                                                                                                                                                                                                 {ICIT, IC2IT}
# international conference data engineering                                                                               {Proceedings / International Conference on Data Engineering, International Conference on Data Engineering}
# international conference information technology  {International Conference on Information Technology, International Conference on Information Technologies, Proceedings of the International Conference on Information Technology}
# international conference parallel processing                                                                 {Proceedings of the International Conference on Parallel Processing, International Conference on Parallel Processing}
# journal experimental psychology                                                                                  {Journal of Experimental Psychology: Learning, Memory and Cognition, Journal of Experimental Psychology: General}
# n                                                                                                                                                                                           {Workshop on ns-3, NSS, Workshop ns-3}
# sc                                                                                                                                                                                                                      {SC, SCSS}

# %%
cleaned_name_to_info = {}
for row in valid_venues.itertuples():
    if row.clean_name not in cleaned_name_to_info:
        cleaned_name_to_info[row.clean_name] = row._asdict()
cleaned_name_to_info
# Out:
# {'journal functional programming': {'Index': 0,
#   'raw_name': 'Journal of functional programming',
#   'id': '58f55ec2-1f5a-4e79-af2a-0046ee1dcd2a',
#   'name': 'Journal of functional programming',
#   'type': 'journal',
#   'alternate_names': ['J funct program',
#    'Journal of Functional Programming',
#    'J Funct Program'],
#   'issn': '0956-7968',
#   'url': 'https://www.cambridge.org/core/journals/journal-of-functional-programming',
#   'alternate_urls': ['http://journals.cambridge.org/jid_JFP'],
#   'alternate_issns': nan,
#   'clean_name': 'journal functional programming'},
#  'j funct program': {'Index': 1,
#   'raw_name': 'J funct program',
#   'id': '58f55ec2-1f5a-4e79-af2a-0046ee1dcd2a',
#   'name': 'Journal of functional programming',
#   'type': 'journal',
#   'alternate_names': ['J funct program',
#    'Journal of Functional Programming',
#    'J Funct Program'],
#   'issn': '0956-7968',
#   'url': 'https://www.cambridge.org/core/journals/journal-of-functional-programming',
#   'alternate_urls': ['http://journals.cambridge.org/jid_JFP'],
#   'alternate_issns': nan,
#   'clean_name': 'j funct program'},
#  'usenix security symposium': {'Index': 4,
#   'raw_name': 'USENIX Security Symposium',
#   'id': '54649c1d-6bcc-4232-9cd1-aa446867b8d0',
#   'name': 'USENIX Security Symposium',
#   'type': 'conference',
#   'alternate_names': ['USENIX Secur Symp'],
#   'issn': nan,
#   'url': 'http://www.usenix.org/events/bytopic/security.html',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'usenix security symposium'},
#  'acm sigmod conference': {'Index': 5,
#   'raw_name': 'ACM SIGMOD Conference',
#   'id': 'f68b9e7e-ad3d-46cb-857d-23e49384143c',
#   'name': 'ACM SIGMOD Conference',
#   'type': 'conference',
#   'alternate_names': ['SIGMOD', 'ACM SIGMOD Conf'],
#   'issn': nan,
#   'url': 'https://sigmod.org/conferences/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'acm sigmod conference'},
#  'sigmod': {'Index': 6,
#   'raw_name': 'SIGMOD',
#   'id': 'f68b9e7e-ad3d-46cb-857d-23e49384143c',
#   'name': 'ACM SIGMOD Conference',
#   'type': 'conference',
#   'alternate_names': ['SIGMOD', 'ACM SIGMOD Conf'],
#   'issn': nan,
#   'url': 'https://sigmod.org/conferences/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'sigmod'},
#  'acm sigmod conf': {'Index': 7,
#   'raw_name': 'ACM SIGMOD Conf',
#   'id': 'f68b9e7e-ad3d-46cb-857d-23e49384143c',
#   'name': 'ACM SIGMOD Conference',
#   'type': 'conference',
#   'alternate_names': ['SIGMOD', 'ACM SIGMOD Conf'],
#   'issn': nan,
#   'url': 'https://sigmod.org/conferences/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'acm sigmod conf'},
#  'international conference human factor computing system': {'Index': 8,
#   'raw_name': 'International Conference on Human Factors in Computing Systems',
#   'id': 'b55b50b1-aae7-47a7-b042-8aecc930073d',
#   'name': 'International Conference on Human Factors in Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['CHI',
#    'Int Conf Hum Factor Comput Syst',
#    'Human Factors in Computing Systems',
#    'Conference on Human Interface',
#    'Conf Hum Interface',
#    'Hum Factor Comput Syst'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigchi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'international conference human factor computing system'},
#  'chi': {'Index': 9,
#   'raw_name': 'CHI',
#   'id': 'b55b50b1-aae7-47a7-b042-8aecc930073d',
#   'name': 'International Conference on Human Factors in Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['CHI',
#    'Int Conf Hum Factor Comput Syst',
#    'Human Factors in Computing Systems',
#    'Conference on Human Interface',
#    'Conf Hum Interface',
#    'Hum Factor Comput Syst'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigchi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'chi'},
#  'int conf hum factor comput syst': {'Index': 10,
#   'raw_name': 'Int Conf Hum Factor Comput Syst',
#   'id': 'b55b50b1-aae7-47a7-b042-8aecc930073d',
#   'name': 'International Conference on Human Factors in Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['CHI',
#    'Int Conf Hum Factor Comput Syst',
#    'Human Factors in Computing Systems',
#    'Conference on Human Interface',
#    'Conf Hum Interface',
#    'Hum Factor Comput Syst'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigchi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'int conf hum factor comput syst'},
#  'human factor computing system': {'Index': 11,
#   'raw_name': 'Human Factors in Computing Systems',
#   'id': 'b55b50b1-aae7-47a7-b042-8aecc930073d',
#   'name': 'International Conference on Human Factors in Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['CHI',
#    'Int Conf Hum Factor Comput Syst',
#    'Human Factors in Computing Systems',
#    'Conference on Human Interface',
#    'Conf Hum Interface',
#    'Hum Factor Comput Syst'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigchi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'human factor computing system'},
#  'conference human interface': {'Index': 12,
#   'raw_name': 'Conference on Human Interface',
#   'id': 'b55b50b1-aae7-47a7-b042-8aecc930073d',
#   'name': 'International Conference on Human Factors in Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['CHI',
#    'Int Conf Hum Factor Comput Syst',
#    'Human Factors in Computing Systems',
#    'Conference on Human Interface',
#    'Conf Hum Interface',
#    'Hum Factor Comput Syst'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigchi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'conference human interface'},
#  'conf hum interface': {'Index': 13,
#   'raw_name': 'Conf Hum Interface',
#   'id': 'b55b50b1-aae7-47a7-b042-8aecc930073d',
#   'name': 'International Conference on Human Factors in Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['CHI',
#    'Int Conf Hum Factor Comput Syst',
#    'Human Factors in Computing Systems',
#    'Conference on Human Interface',
#    'Conf Hum Interface',
#    'Hum Factor Comput Syst'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigchi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'conf hum interface'},
#  'hum factor comput syst': {'Index': 14,
#   'raw_name': 'Hum Factor Comput Syst',
#   'id': 'b55b50b1-aae7-47a7-b042-8aecc930073d',
#   'name': 'International Conference on Human Factors in Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['CHI',
#    'Int Conf Hum Factor Comput Syst',
#    'Human Factors in Computing Systems',
#    'Conference on Human Interface',
#    'Conf Hum Interface',
#    'Hum Factor Comput Syst'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigchi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'hum factor comput syst'},
#  'sigact news': {'Index': 15,
#   'raw_name': 'Sigact News',
#   'id': 'b0f145c0-41f1-48c7-a514-e3f583b57d74',
#   'name': 'Sigact News',
#   'type': 'journal',
#   'alternate_names': nan,
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'sigact news'},
#  'acm sigplan symposium programming language design implementation': {'Index': 16,
#   'raw_name': 'ACM-SIGPLAN Symposium on Programming Language Design and Implementation',
#   'id': 'a00a1a4f-16c6-4360-a8b3-a3f88d2fe78f',
#   'name': 'ACM-SIGPLAN Symposium on Programming Language Design and Implementation',
#   'type': 'conference',
#   'alternate_names': ['ACM-SIGPLAN Symp Program Lang Des Implement',
#    'Program Lang Des Implement',
#    'Programming Language Design and Implementation',
#    'PLDI'],
#   'issn': nan,
#   'url': 'http://portal.acm.org/proceedings/pldi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'acm sigplan symposium programming language design implementation'},
#  'acm sigplan symp program lang de implement': {'Index': 17,
#   'raw_name': 'ACM-SIGPLAN Symp Program Lang Des Implement',
#   'id': 'a00a1a4f-16c6-4360-a8b3-a3f88d2fe78f',
#   'name': 'ACM-SIGPLAN Symposium on Programming Language Design and Implementation',
#   'type': 'conference',
#   'alternate_names': ['ACM-SIGPLAN Symp Program Lang Des Implement',
#    'Program Lang Des Implement',
#    'Programming Language Design and Implementation',
#    'PLDI'],
#   'issn': nan,
#   'url': 'http://portal.acm.org/proceedings/pldi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'acm sigplan symp program lang de implement'},
#  'program lang de implement': {'Index': 18,
#   'raw_name': 'Program Lang Des Implement',
#   'id': 'a00a1a4f-16c6-4360-a8b3-a3f88d2fe78f',
#   'name': 'ACM-SIGPLAN Symposium on Programming Language Design and Implementation',
#   'type': 'conference',
#   'alternate_names': ['ACM-SIGPLAN Symp Program Lang Des Implement',
#    'Program Lang Des Implement',
#    'Programming Language Design and Implementation',
#    'PLDI'],
#   'issn': nan,
#   'url': 'http://portal.acm.org/proceedings/pldi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'program lang de implement'},
#  'programming language design implementation': {'Index': 19,
#   'raw_name': 'Programming Language Design and Implementation',
#   'id': 'a00a1a4f-16c6-4360-a8b3-a3f88d2fe78f',
#   'name': 'ACM-SIGPLAN Symposium on Programming Language Design and Implementation',
#   'type': 'conference',
#   'alternate_names': ['ACM-SIGPLAN Symp Program Lang Des Implement',
#    'Program Lang Des Implement',
#    'Programming Language Design and Implementation',
#    'PLDI'],
#   'issn': nan,
#   'url': 'http://portal.acm.org/proceedings/pldi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'programming language design implementation'},
#  'pldi': {'Index': 20,
#   'raw_name': 'PLDI',
#   'id': 'a00a1a4f-16c6-4360-a8b3-a3f88d2fe78f',
#   'name': 'ACM-SIGPLAN Symposium on Programming Language Design and Implementation',
#   'type': 'conference',
#   'alternate_names': ['ACM-SIGPLAN Symp Program Lang Des Implement',
#    'Program Lang Des Implement',
#    'Programming Language Design and Implementation',
#    'PLDI'],
#   'issn': nan,
#   'url': 'http://portal.acm.org/proceedings/pldi/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'pldi'},
#  'queue': {'Index': 21,
#   'raw_name': 'Queue',
#   'id': '4bd27ad1-f6fa-4340-9d9d-c62ac5be6fc0',
#   'name': 'Queue',
#   'type': 'journal',
#   'alternate_names': ['ACM Queue'],
#   'issn': '1542-7730',
#   'url': 'http://portal.acm.org/queue',
#   'alternate_urls': ['http://www.acmqueue.org/'],
#   'alternate_issns': nan,
#   'clean_name': 'queue'},
#  'acm queue': {'Index': 22,
#   'raw_name': 'ACM Queue',
#   'id': '4bd27ad1-f6fa-4340-9d9d-c62ac5be6fc0',
#   'name': 'Queue',
#   'type': 'journal',
#   'alternate_names': ['ACM Queue'],
#   'issn': '1542-7730',
#   'url': 'http://portal.acm.org/queue',
#   'alternate_urls': ['http://www.acmqueue.org/'],
#   'alternate_issns': nan,
#   'clean_name': 'acm queue'},
#  'computer': {'Index': 23,
#   'raw_name': 'Computer',
#   'id': 'f6572f66-2623-4a5e-b0d9-4a5028dea98f',
#   'name': 'Computer',
#   'type': 'journal',
#   'alternate_names': ['IEEE Computer', 'IEEE Comput'],
#   'issn': '0018-9162',
#   'url': 'http://www.computer.org/computer',
#   'alternate_urls': ['https://ieeexplore.ieee.org/servlet/opac?punumber=2',
#    'http://www.computer.org/portal/site/ieeecs/index.jsp',
#    'https://ieeexplore.ieee.org/xpl/RecentIssue.jsp?punumber=2'],
#   'alternate_issns': nan,
#   'clean_name': 'computer'},
#  'ieee computer': {'Index': 24,
#   'raw_name': 'IEEE Computer',
#   'id': 'f6572f66-2623-4a5e-b0d9-4a5028dea98f',
#   'name': 'Computer',
#   'type': 'journal',
#   'alternate_names': ['IEEE Computer', 'IEEE Comput'],
#   'issn': '0018-9162',
#   'url': 'http://www.computer.org/computer',
#   'alternate_urls': ['https://ieeexplore.ieee.org/servlet/opac?punumber=2',
#    'http://www.computer.org/portal/site/ieeecs/index.jsp',
#    'https://ieeexplore.ieee.org/xpl/RecentIssue.jsp?punumber=2'],
#   'alternate_issns': nan,
#   'clean_name': 'ieee computer'},
#  'ieee comput': {'Index': 25,
#   'raw_name': 'IEEE Comput',
#   'id': 'f6572f66-2623-4a5e-b0d9-4a5028dea98f',
#   'name': 'Computer',
#   'type': 'journal',
#   'alternate_names': ['IEEE Computer', 'IEEE Comput'],
#   'issn': '0018-9162',
#   'url': 'http://www.computer.org/computer',
#   'alternate_urls': ['https://ieeexplore.ieee.org/servlet/opac?punumber=2',
#    'http://www.computer.org/portal/site/ieeecs/index.jsp',
#    'https://ieeexplore.ieee.org/xpl/RecentIssue.jsp?punumber=2'],
#   'alternate_issns': nan,
#   'clean_name': 'ieee comput'},
#  'mathematics computation': {'Index': 26,
#   'raw_name': 'Mathematics of Computation',
#   'id': 'f1022129-db8f-4da5-b0c4-89602aeaea04',
#   'name': 'Mathematics of Computation',
#   'type': 'journal',
#   'alternate_names': ['Mathematical computation',
#    'Math comput',
#    'Math Comput'],
#   'issn': '0025-5718',
#   'url': 'http://www.ams.org/mcom/',
#   'alternate_urls': ['http://www.ivypub.org/mc/',
#    'http://www.ams.org/publications/journals/journalsframework/mcom',
#    'https://www.jstor.org/journal/mathcomp',
#    'http://www.jstor.org/journals/00255718.html',
#    'https://www.ams.org/publications/journals/journalsframework/mcom'],
#   'alternate_issns': ['2327-0519', '2327-0527'],
#   'clean_name': 'mathematics computation'},
#  'mathematical computation': {'Index': 27,
#   'raw_name': 'Mathematical computation',
#   'id': 'f1022129-db8f-4da5-b0c4-89602aeaea04',
#   'name': 'Mathematics of Computation',
#   'type': 'journal',
#   'alternate_names': ['Mathematical computation',
#    'Math comput',
#    'Math Comput'],
#   'issn': '0025-5718',
#   'url': 'http://www.ams.org/mcom/',
#   'alternate_urls': ['http://www.ivypub.org/mc/',
#    'http://www.ams.org/publications/journals/journalsframework/mcom',
#    'https://www.jstor.org/journal/mathcomp',
#    'http://www.jstor.org/journals/00255718.html',
#    'https://www.ams.org/publications/journals/journalsframework/mcom'],
#   'alternate_issns': ['2327-0519', '2327-0527'],
#   'clean_name': 'mathematical computation'},
#  'math comput': {'Index': 28,
#   'raw_name': 'Math comput',
#   'id': 'f1022129-db8f-4da5-b0c4-89602aeaea04',
#   'name': 'Mathematics of Computation',
#   'type': 'journal',
#   'alternate_names': ['Mathematical computation',
#    'Math comput',
#    'Math Comput'],
#   'issn': '0025-5718',
#   'url': 'http://www.ams.org/mcom/',
#   'alternate_urls': ['http://www.ivypub.org/mc/',
#    'http://www.ams.org/publications/journals/journalsframework/mcom',
#    'https://www.jstor.org/journal/mathcomp',
#    'http://www.jstor.org/journals/00255718.html',
#    'https://www.ams.org/publications/journals/journalsframework/mcom'],
#   'alternate_issns': ['2327-0519', '2327-0527'],
#   'clean_name': 'math comput'},
#  'conference functional programming language computer architecture': {'Index': 30,
#   'raw_name': 'Conference on Functional Programming Languages and Computer Architecture',
#   'id': 'b817908e-1775-414c-88da-a90ad4cf22a9',
#   'name': 'Conference on Functional Programming Languages and Computer Architecture',
#   'type': 'conference',
#   'alternate_names': ['FPCA', 'Conf Funct Program Lang Comput Archit'],
#   'issn': nan,
#   'url': 'http://www.acm.org/pubs/contents/proceedings/fp/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'conference functional programming language computer architecture'},
#  'fpca': {'Index': 31,
#   'raw_name': 'FPCA',
#   'id': 'b817908e-1775-414c-88da-a90ad4cf22a9',
#   'name': 'Conference on Functional Programming Languages and Computer Architecture',
#   'type': 'conference',
#   'alternate_names': ['FPCA', 'Conf Funct Program Lang Comput Archit'],
#   'issn': nan,
#   'url': 'http://www.acm.org/pubs/contents/proceedings/fp/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'fpca'},
#  'conf funct program lang comput archit': {'Index': 32,
#   'raw_name': 'Conf Funct Program Lang Comput Archit',
#   'id': 'b817908e-1775-414c-88da-a90ad4cf22a9',
#   'name': 'Conference on Functional Programming Languages and Computer Architecture',
#   'type': 'conference',
#   'alternate_names': ['FPCA', 'Conf Funct Program Lang Comput Archit'],
#   'issn': nan,
#   'url': 'http://www.acm.org/pubs/contents/proceedings/fp/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'conf funct program lang comput archit'},
#  'international conference architectural support programming language operating system': {'Index': 33,
#   'raw_name': 'International Conference on Architectural Support for Programming Languages and Operating Systems',
#   'id': 'd4610af5-85e0-480b-8773-5c71d92a7b99',
#   'name': 'International Conference on Architectural Support for Programming Languages and Operating Systems',
#   'type': 'conference',
#   'alternate_names': ['ASPLOS',
#    'Int Conf Archit Support Program Lang Oper Syst',
#    'Archit Support Program Lang Oper Syst',
#    'Architectural Support for Programming Languages and Operating Systems'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigplan/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'international conference architectural support programming language operating system'},
#  'asplos': {'Index': 34,
#   'raw_name': 'ASPLOS',
#   'id': 'd4610af5-85e0-480b-8773-5c71d92a7b99',
#   'name': 'International Conference on Architectural Support for Programming Languages and Operating Systems',
#   'type': 'conference',
#   'alternate_names': ['ASPLOS',
#    'Int Conf Archit Support Program Lang Oper Syst',
#    'Archit Support Program Lang Oper Syst',
#    'Architectural Support for Programming Languages and Operating Systems'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigplan/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'asplos'},
#  'int conf archit support program lang oper syst': {'Index': 35,
#   'raw_name': 'Int Conf Archit Support Program Lang Oper Syst',
#   'id': 'd4610af5-85e0-480b-8773-5c71d92a7b99',
#   'name': 'International Conference on Architectural Support for Programming Languages and Operating Systems',
#   'type': 'conference',
#   'alternate_names': ['ASPLOS',
#    'Int Conf Archit Support Program Lang Oper Syst',
#    'Archit Support Program Lang Oper Syst',
#    'Architectural Support for Programming Languages and Operating Systems'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigplan/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'int conf archit support program lang oper syst'},
#  'archit support program lang oper syst': {'Index': 36,
#   'raw_name': 'Archit Support Program Lang Oper Syst',
#   'id': 'd4610af5-85e0-480b-8773-5c71d92a7b99',
#   'name': 'International Conference on Architectural Support for Programming Languages and Operating Systems',
#   'type': 'conference',
#   'alternate_names': ['ASPLOS',
#    'Int Conf Archit Support Program Lang Oper Syst',
#    'Archit Support Program Lang Oper Syst',
#    'Architectural Support for Programming Languages and Operating Systems'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigplan/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'archit support program lang oper syst'},
#  'architectural support programming language operating system': {'Index': 37,
#   'raw_name': 'Architectural Support for Programming Languages and Operating Systems',
#   'id': 'd4610af5-85e0-480b-8773-5c71d92a7b99',
#   'name': 'International Conference on Architectural Support for Programming Languages and Operating Systems',
#   'type': 'conference',
#   'alternate_names': ['ASPLOS',
#    'Int Conf Archit Support Program Lang Oper Syst',
#    'Archit Support Program Lang Oper Syst',
#    'Architectural Support for Programming Languages and Operating Systems'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigplan/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'architectural support programming language operating system'},
#  'iacr cryptology eprint archive': {'Index': 38,
#   'raw_name': 'IACR Cryptology ePrint Archive',
#   'id': '166fd2b5-a928-4a98-a449-3b90935cc101',
#   'name': 'IACR Cryptology ePrint Archive',
#   'type': 'journal',
#   'alternate_names': ['IACR Cryptol eprint Arch'],
#   'issn': nan,
#   'url': 'http://eprint.iacr.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'iacr cryptology eprint archive'},
#  'iacr cryptol eprint arch': {'Index': 39,
#   'raw_name': 'IACR Cryptol eprint Arch',
#   'id': '166fd2b5-a928-4a98-a449-3b90935cc101',
#   'name': 'IACR Cryptology ePrint Archive',
#   'type': 'journal',
#   'alternate_names': ['IACR Cryptol eprint Arch'],
#   'issn': nan,
#   'url': 'http://eprint.iacr.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'iacr cryptol eprint arch'},
#  'international conference artificial intelligence pattern recognition': {'Index': 40,
#   'raw_name': 'International Conference on Artificial Intelligence and Pattern Recognition',
#   'id': '596979b9-69c7-4a3a-ac4d-c70580b8fd80',
#   'name': 'International Conference on Artificial Intelligence and Pattern Recognition',
#   'type': 'conference',
#   'alternate_names': ['Appl Imag Pattern Recognit Workshop',
#    'Int Conf Artif Intell Pattern Recognit',
#    'AIPR',
#    'Applied Imagery Pattern Recognition Workshop',
#    'Artificial Intelligence and Pattern Recognition',
#    'Artif Intell Pattern Recognit'],
#   'issn': nan,
#   'url': 'http://www.aipr-workshop.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'international conference artificial intelligence pattern recognition'},
#  'appl imag pattern recognit': {'Index': 41,
#   'raw_name': 'Appl Imag Pattern Recognit Workshop',
#   'id': '596979b9-69c7-4a3a-ac4d-c70580b8fd80',
#   'name': 'International Conference on Artificial Intelligence and Pattern Recognition',
#   'type': 'conference',
#   'alternate_names': ['Appl Imag Pattern Recognit Workshop',
#    'Int Conf Artif Intell Pattern Recognit',
#    'AIPR',
#    'Applied Imagery Pattern Recognition Workshop',
#    'Artificial Intelligence and Pattern Recognition',
#    'Artif Intell Pattern Recognit'],
#   'issn': nan,
#   'url': 'http://www.aipr-workshop.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'appl imag pattern recognit'},
#  'int conf artif intell pattern recognit': {'Index': 42,
#   'raw_name': 'Int Conf Artif Intell Pattern Recognit',
#   'id': '596979b9-69c7-4a3a-ac4d-c70580b8fd80',
#   'name': 'International Conference on Artificial Intelligence and Pattern Recognition',
#   'type': 'conference',
#   'alternate_names': ['Appl Imag Pattern Recognit Workshop',
#    'Int Conf Artif Intell Pattern Recognit',
#    'AIPR',
#    'Applied Imagery Pattern Recognition Workshop',
#    'Artificial Intelligence and Pattern Recognition',
#    'Artif Intell Pattern Recognit'],
#   'issn': nan,
#   'url': 'http://www.aipr-workshop.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'int conf artif intell pattern recognit'},
#  'aipr': {'Index': 43,
#   'raw_name': 'AIPR',
#   'id': '596979b9-69c7-4a3a-ac4d-c70580b8fd80',
#   'name': 'International Conference on Artificial Intelligence and Pattern Recognition',
#   'type': 'conference',
#   'alternate_names': ['Appl Imag Pattern Recognit Workshop',
#    'Int Conf Artif Intell Pattern Recognit',
#    'AIPR',
#    'Applied Imagery Pattern Recognition Workshop',
#    'Artificial Intelligence and Pattern Recognition',
#    'Artif Intell Pattern Recognit'],
#   'issn': nan,
#   'url': 'http://www.aipr-workshop.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'aipr'},
#  'applied imagery pattern recognition': {'Index': 44,
#   'raw_name': 'Applied Imagery Pattern Recognition Workshop',
#   'id': '596979b9-69c7-4a3a-ac4d-c70580b8fd80',
#   'name': 'International Conference on Artificial Intelligence and Pattern Recognition',
#   'type': 'conference',
#   'alternate_names': ['Appl Imag Pattern Recognit Workshop',
#    'Int Conf Artif Intell Pattern Recognit',
#    'AIPR',
#    'Applied Imagery Pattern Recognition Workshop',
#    'Artificial Intelligence and Pattern Recognition',
#    'Artif Intell Pattern Recognit'],
#   'issn': nan,
#   'url': 'http://www.aipr-workshop.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'applied imagery pattern recognition'},
#  'artificial intelligence pattern recognition': {'Index': 45,
#   'raw_name': 'Artificial Intelligence and Pattern Recognition',
#   'id': '596979b9-69c7-4a3a-ac4d-c70580b8fd80',
#   'name': 'International Conference on Artificial Intelligence and Pattern Recognition',
#   'type': 'conference',
#   'alternate_names': ['Appl Imag Pattern Recognit Workshop',
#    'Int Conf Artif Intell Pattern Recognit',
#    'AIPR',
#    'Applied Imagery Pattern Recognition Workshop',
#    'Artificial Intelligence and Pattern Recognition',
#    'Artif Intell Pattern Recognit'],
#   'issn': nan,
#   'url': 'http://www.aipr-workshop.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'artificial intelligence pattern recognition'},
#  'artif intell pattern recognit': {'Index': 46,
#   'raw_name': 'Artif Intell Pattern Recognit',
#   'id': '596979b9-69c7-4a3a-ac4d-c70580b8fd80',
#   'name': 'International Conference on Artificial Intelligence and Pattern Recognition',
#   'type': 'conference',
#   'alternate_names': ['Appl Imag Pattern Recognit Workshop',
#    'Int Conf Artif Intell Pattern Recognit',
#    'AIPR',
#    'Applied Imagery Pattern Recognition Workshop',
#    'Artificial Intelligence and Pattern Recognition',
#    'Artif Intell Pattern Recognit'],
#   'issn': nan,
#   'url': 'http://www.aipr-workshop.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'artif intell pattern recognit'},
#  'acm transaction graphic': {'Index': 47,
#   'raw_name': 'ACM Transactions on Graphics',
#   'id': 'aab03e41-f80d-48b3-89bd-60eeeceafc7d',
#   'name': 'ACM Transactions on Graphics',
#   'type': 'journal',
#   'alternate_names': ['ACM Trans Graph'],
#   'issn': '0730-0301',
#   'url': 'http://www.acm.org/tog/',
#   'alternate_urls': ['http://portal.acm.org/tog', 'https://tog.acm.org/'],
#   'alternate_issns': nan,
#   'clean_name': 'acm transaction graphic'},
#  'acm trans graph': {'Index': 48,
#   'raw_name': 'ACM Trans Graph',
#   'id': 'aab03e41-f80d-48b3-89bd-60eeeceafc7d',
#   'name': 'ACM Transactions on Graphics',
#   'type': 'journal',
#   'alternate_names': ['ACM Trans Graph'],
#   'issn': '0730-0301',
#   'url': 'http://www.acm.org/tog/',
#   'alternate_urls': ['http://portal.acm.org/tog', 'https://tog.acm.org/'],
#   'alternate_issns': nan,
#   'clean_name': 'acm trans graph'},
#  'ieee transaction knowledge data engineering': {'Index': 49,
#   'raw_name': 'IEEE Transactions on Knowledge and Data Engineering',
#   'id': 'c6840156-ee10-4d78-8832-7f8909811576',
#   'name': 'IEEE Transactions on Knowledge and Data Engineering',
#   'type': 'journal',
#   'alternate_names': ['IEEE Trans Knowl Data Eng'],
#   'issn': '1041-4347',
#   'url': 'https://www.computer.org/web/tkde',
#   'alternate_urls': ['http://ieeexplore.ieee.org/servlet/opac?punumber=69'],
#   'alternate_issns': nan,
#   'clean_name': 'ieee transaction knowledge data engineering'},
#  'ieee trans knowl data eng': {'Index': 50,
#   'raw_name': 'IEEE Trans Knowl Data Eng',
#   'id': 'c6840156-ee10-4d78-8832-7f8909811576',
#   'name': 'IEEE Transactions on Knowledge and Data Engineering',
#   'type': 'journal',
#   'alternate_names': ['IEEE Trans Knowl Data Eng'],
#   'issn': '1041-4347',
#   'url': 'https://www.computer.org/web/tkde',
#   'alternate_urls': ['http://ieeexplore.ieee.org/servlet/opac?punumber=69'],
#   'alternate_issns': nan,
#   'clean_name': 'ieee trans knowl data eng'},
#  'data mining knowledge discovery': {'Index': 51,
#   'raw_name': 'Data mining and knowledge discovery',
#   'id': 'd263025a-9eaf-443f-9bbf-72377e8d22a6',
#   'name': 'Data mining and knowledge discovery',
#   'type': 'journal',
#   'alternate_names': ['Data Mining and Knowledge Discovery',
#    'Data Min Knowl Discov',
#    'Data min knowl discov'],
#   'issn': '1384-5810',
#   'url': 'https://www.springer.com/computer/database+management+&+information+retrieval/journal/10618',
#   'alternate_urls': ['https://link.springer.com/journal/10618',
#    'http://www.springer.com/computer/database+management+&+information+retrieval/journal/10618'],
#   'alternate_issns': nan,
#   'clean_name': 'data mining knowledge discovery'},
#  'data min knowl discov': {'Index': 53,
#   'raw_name': 'Data Min Knowl Discov',
#   'id': 'd263025a-9eaf-443f-9bbf-72377e8d22a6',
#   'name': 'Data mining and knowledge discovery',
#   'type': 'journal',
#   'alternate_names': ['Data Mining and Knowledge Discovery',
#    'Data Min Knowl Discov',
#    'Data min knowl discov'],
#   'issn': '1384-5810',
#   'url': 'https://www.springer.com/computer/database+management+&+information+retrieval/journal/10618',
#   'alternate_urls': ['https://link.springer.com/journal/10618',
#    'http://www.springer.com/computer/database+management+&+information+retrieval/journal/10618'],
#   'alternate_issns': nan,
#   'clean_name': 'data min knowl discov'},
#  'lecture note computer science': {'Index': 55,
#   'raw_name': 'Lecture Notes in Computer Science',
#   'id': '2f5d0e8a-faad-4f10-b323-2b2e3c439a78',
#   'name': 'Lecture Notes in Computer Science',
#   'type': 'journal',
#   'alternate_names': ['LNCS',
#    'Transactions on Computational Systems Biology',
#    'Trans Comput Syst Biology',
#    'Lect Note Comput Sci'],
#   'issn': '0302-9743',
#   'url': 'http://www.springer.com/lncs',
#   'alternate_urls': ['http://www.springer.com/sgw/cda/frontpage/0,11855,1-164-2-73659-0,00.html',
#    'https://link.springer.com/bookseries/558',
#    'http://link.springer.com/search?query="Transactions+on+Computational+Systems+Biology"'],
#   'alternate_issns': ['1861-2059', '1861-2075', '1866-4733'],
#   'clean_name': 'lecture note computer science'},
#  'lncs': {'Index': 56,
#   'raw_name': 'LNCS',
#   'id': '2f5d0e8a-faad-4f10-b323-2b2e3c439a78',
#   'name': 'Lecture Notes in Computer Science',
#   'type': 'journal',
#   'alternate_names': ['LNCS',
#    'Transactions on Computational Systems Biology',
#    'Trans Comput Syst Biology',
#    'Lect Note Comput Sci'],
#   'issn': '0302-9743',
#   'url': 'http://www.springer.com/lncs',
#   'alternate_urls': ['http://www.springer.com/sgw/cda/frontpage/0,11855,1-164-2-73659-0,00.html',
#    'https://link.springer.com/bookseries/558',
#    'http://link.springer.com/search?query="Transactions+on+Computational+Systems+Biology"'],
#   'alternate_issns': ['1861-2059', '1861-2075', '1866-4733'],
#   'clean_name': 'lncs'},
#  'transaction computational system biology': {'Index': 57,
#   'raw_name': 'Transactions on Computational Systems Biology',
#   'id': '2f5d0e8a-faad-4f10-b323-2b2e3c439a78',
#   'name': 'Lecture Notes in Computer Science',
#   'type': 'journal',
#   'alternate_names': ['LNCS',
#    'Transactions on Computational Systems Biology',
#    'Trans Comput Syst Biology',
#    'Lect Note Comput Sci'],
#   'issn': '0302-9743',
#   'url': 'http://www.springer.com/lncs',
#   'alternate_urls': ['http://www.springer.com/sgw/cda/frontpage/0,11855,1-164-2-73659-0,00.html',
#    'https://link.springer.com/bookseries/558',
#    'http://link.springer.com/search?query="Transactions+on+Computational+Systems+Biology"'],
#   'alternate_issns': ['1861-2059', '1861-2075', '1866-4733'],
#   'clean_name': 'transaction computational system biology'},
#  'trans comput syst biology': {'Index': 58,
#   'raw_name': 'Trans Comput Syst Biology',
#   'id': '2f5d0e8a-faad-4f10-b323-2b2e3c439a78',
#   'name': 'Lecture Notes in Computer Science',
#   'type': 'journal',
#   'alternate_names': ['LNCS',
#    'Transactions on Computational Systems Biology',
#    'Trans Comput Syst Biology',
#    'Lect Note Comput Sci'],
#   'issn': '0302-9743',
#   'url': 'http://www.springer.com/lncs',
#   'alternate_urls': ['http://www.springer.com/sgw/cda/frontpage/0,11855,1-164-2-73659-0,00.html',
#    'https://link.springer.com/bookseries/558',
#    'http://link.springer.com/search?query="Transactions+on+Computational+Systems+Biology"'],
#   'alternate_issns': ['1861-2059', '1861-2075', '1866-4733'],
#   'clean_name': 'trans comput syst biology'},
#  'lect note comput sci': {'Index': 59,
#   'raw_name': 'Lect Note Comput Sci',
#   'id': '2f5d0e8a-faad-4f10-b323-2b2e3c439a78',
#   'name': 'Lecture Notes in Computer Science',
#   'type': 'journal',
#   'alternate_names': ['LNCS',
#    'Transactions on Computational Systems Biology',
#    'Trans Comput Syst Biology',
#    'Lect Note Comput Sci'],
#   'issn': '0302-9743',
#   'url': 'http://www.springer.com/lncs',
#   'alternate_urls': ['http://www.springer.com/sgw/cda/frontpage/0,11855,1-164-2-73659-0,00.html',
#    'https://link.springer.com/bookseries/558',
#    'http://link.springer.com/search?query="Transactions+on+Computational+Systems+Biology"'],
#   'alternate_issns': ['1861-2059', '1861-2075', '1866-4733'],
#   'clean_name': 'lect note comput sci'},
#  'computer law journal': {'Index': 60,
#   'raw_name': 'Computer/law journal',
#   'id': 'aa746a02-d187-42c2-bdf9-df6a5d4e648c',
#   'name': 'Computer/law journal',
#   'type': 'journal',
#   'alternate_names': ['Computer journal',
#    'The Computer Journal',
#    'Comput j',
#    'Comput J'],
#   'issn': '0164-8756',
#   'url': 'https://repository.jmls.edu/jitpl/all_issues.html',
#   'alternate_urls': ['http://comjnl.oxfordjournals.org/'],
#   'alternate_issns': ['0010-4620'],
#   'clean_name': 'computer law journal'},
#  'computer journal': {'Index': 61,
#   'raw_name': 'Computer journal',
#   'id': 'aa746a02-d187-42c2-bdf9-df6a5d4e648c',
#   'name': 'Computer/law journal',
#   'type': 'journal',
#   'alternate_names': ['Computer journal',
#    'The Computer Journal',
#    'Comput j',
#    'Comput J'],
#   'issn': '0164-8756',
#   'url': 'https://repository.jmls.edu/jitpl/all_issues.html',
#   'alternate_urls': ['http://comjnl.oxfordjournals.org/'],
#   'alternate_issns': ['0010-4620'],
#   'clean_name': 'computer journal'},
#  'comput j': {'Index': 63,
#   'raw_name': 'Comput j',
#   'id': 'aa746a02-d187-42c2-bdf9-df6a5d4e648c',
#   'name': 'Computer/law journal',
#   'type': 'journal',
#   'alternate_names': ['Computer journal',
#    'The Computer Journal',
#    'Comput j',
#    'Comput J'],
#   'issn': '0164-8756',
#   'url': 'https://repository.jmls.edu/jitpl/all_issues.html',
#   'alternate_urls': ['http://comjnl.oxfordjournals.org/'],
#   'alternate_issns': ['0010-4620'],
#   'clean_name': 'comput j'},
#  'hot topic operating system': {'Index': 65,
#   'raw_name': 'Workshop on Hot Topics in Operating Systems',
#   'id': 'e29f3ae1-4574-4fd4-9f5b-498495cb7952',
#   'name': 'USENIX Workshop on Hot Topics in Operating Systems',
#   'type': 'conference',
#   'alternate_names': ['USENIX Workshop Hot Top Oper Syst',
#    'Workshop on Hot Topics in Operating Systems',
#    'HotOS',
#    'Workshop Hot Top Oper Syst'],
#   'issn': nan,
#   'url': 'http://www.wikicfp.com/cfp/program?id=1213',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'hot topic operating system'},
#  'information processing management': {'Index': 66,
#   'raw_name': 'Information Processing & Management',
#   'id': '37f5b9b7-f828-4ae1-a174-45b538cbd4e4',
#   'name': 'Information Processing & Management',
#   'type': 'journal',
#   'alternate_names': ['Inf Process Manag',
#    'Inf Process  Manag',
#    'Information Processing and Management'],
#   'issn': '0306-4573',
#   'url': 'http://www.elsevier.com/wps/find/journaldescription.cws_home/244/description#description',
#   'alternate_urls': ['https://www.journals.elsevier.com/information-processing-and-management/',
#    'http://www.sciencedirect.com/science/journal/03064573',
#    'http://www.journals.elsevier.com/information-processing-and-management/'],
#   'alternate_issns': nan,
#   'clean_name': 'information processing management'},
#  'inf process manag': {'Index': 67,
#   'raw_name': 'Inf Process Manag',
#   'id': '37f5b9b7-f828-4ae1-a174-45b538cbd4e4',
#   'name': 'Information Processing & Management',
#   'type': 'journal',
#   'alternate_names': ['Inf Process Manag',
#    'Inf Process  Manag',
#    'Information Processing and Management'],
#   'issn': '0306-4573',
#   'url': 'http://www.elsevier.com/wps/find/journaldescription.cws_home/244/description#description',
#   'alternate_urls': ['https://www.journals.elsevier.com/information-processing-and-management/',
#    'http://www.sciencedirect.com/science/journal/03064573',
#    'http://www.journals.elsevier.com/information-processing-and-management/'],
#   'alternate_issns': nan,
#   'clean_name': 'inf process manag'},
#  'parallel computing': {'Index': 70,
#   'raw_name': 'Parallel Computing',
#   'id': '6eb081a0-9eb2-4189-b94d-5557aadd5645',
#   'name': 'Parallel Computing',
#   'type': 'journal',
#   'alternate_names': ['Parallel Comput'],
#   'issn': '0167-8191',
#   'url': 'http://www.elsevier.com/wps/find/journaldescription.cws_home/505617/description#description',
#   'alternate_urls': ['http://www.sciencedirect.com/science/journal/01678191',
#    'https://www.journals.elsevier.com/parallel-computing'],
#   'alternate_issns': nan,
#   'clean_name': 'parallel computing'},
#  'parallel comput': {'Index': 71,
#   'raw_name': 'Parallel Comput',
#   'id': '6eb081a0-9eb2-4189-b94d-5557aadd5645',
#   'name': 'Parallel Computing',
#   'type': 'journal',
#   'alternate_names': ['Parallel Comput'],
#   'issn': '0167-8191',
#   'url': 'http://www.elsevier.com/wps/find/journaldescription.cws_home/505617/description#description',
#   'alternate_urls': ['http://www.sciencedirect.com/science/journal/01678191',
#    'https://www.journals.elsevier.com/parallel-computing'],
#   'alternate_issns': nan,
#   'clean_name': 'parallel comput'},
#  'human language technology baltic perspectiv': {'Index': 72,
#   'raw_name': 'Human Language Technology - The Baltic Perspectiv',
#   'id': 'f8e3f8d0-0f40-48c0-b3c0-0c540237b859',
#   'name': 'Human Language Technology - The Baltic Perspectiv',
#   'type': 'conference',
#   'alternate_names': ['Human Language Technology',
#    'HLT',
#    'Hum Lang Technol',
#    'Hum Lang Technol  Balt Perspect'],
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'human language technology baltic perspectiv'},
#  'human language technology': {'Index': 73,
#   'raw_name': 'Human Language Technology',
#   'id': 'f8e3f8d0-0f40-48c0-b3c0-0c540237b859',
#   'name': 'Human Language Technology - The Baltic Perspectiv',
#   'type': 'conference',
#   'alternate_names': ['Human Language Technology',
#    'HLT',
#    'Hum Lang Technol',
#    'Hum Lang Technol  Balt Perspect'],
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'human language technology'},
#  'hlt': {'Index': 74,
#   'raw_name': 'HLT',
#   'id': 'f8e3f8d0-0f40-48c0-b3c0-0c540237b859',
#   'name': 'Human Language Technology - The Baltic Perspectiv',
#   'type': 'conference',
#   'alternate_names': ['Human Language Technology',
#    'HLT',
#    'Hum Lang Technol',
#    'Hum Lang Technol  Balt Perspect'],
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'hlt'},
#  'hum lang technol': {'Index': 75,
#   'raw_name': 'Hum Lang Technol',
#   'id': 'f8e3f8d0-0f40-48c0-b3c0-0c540237b859',
#   'name': 'Human Language Technology - The Baltic Perspectiv',
#   'type': 'conference',
#   'alternate_names': ['Human Language Technology',
#    'HLT',
#    'Hum Lang Technol',
#    'Hum Lang Technol  Balt Perspect'],
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'hum lang technol'},
#  'hum lang technol balt perspect': {'Index': 76,
#   'raw_name': 'Hum Lang Technol  Balt Perspect',
#   'id': 'f8e3f8d0-0f40-48c0-b3c0-0c540237b859',
#   'name': 'Human Language Technology - The Baltic Perspectiv',
#   'type': 'conference',
#   'alternate_names': ['Human Language Technology',
#    'HLT',
#    'Hum Lang Technol',
#    'Hum Lang Technol  Balt Perspect'],
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'hum lang technol balt perspect'},
#  'engineering self organising system': {'Index': 77,
#   'raw_name': 'Engineering Self-Organising Systems',
#   'id': 'dd93066e-af6f-4c14-aa3c-93a6b3417c06',
#   'name': 'Engineering Self-Organising Systems',
#   'type': 'conference',
#   'alternate_names': ['ESOA', 'Eng Self-organising Syst'],
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'engineering self organising system'},
#  'esoa': {'Index': 78,
#   'raw_name': 'ESOA',
#   'id': 'dd93066e-af6f-4c14-aa3c-93a6b3417c06',
#   'name': 'Engineering Self-Organising Systems',
#   'type': 'conference',
#   'alternate_names': ['ESOA', 'Eng Self-organising Syst'],
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'esoa'},
#  'eng self organising syst': {'Index': 79,
#   'raw_name': 'Eng Self-organising Syst',
#   'id': 'dd93066e-af6f-4c14-aa3c-93a6b3417c06',
#   'name': 'Engineering Self-Organising Systems',
#   'type': 'conference',
#   'alternate_names': ['ESOA', 'Eng Self-organising Syst'],
#   'issn': nan,
#   'url': nan,
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'eng self organising syst'},
#  'ieee international symposium network computing application': {'Index': 80,
#   'raw_name': 'IEEE International Symposium on Network Computing and Applications',
#   'id': 'f3fc2b06-d105-40f5-a248-64cf28379e9c',
#   'name': 'IEEE International Symposium on Network Computing and Applications',
#   'type': 'conference',
#   'alternate_names': ['NCA',
#    'IEEE Int Symp Netw Comput Appl',
#    'Network Computing and Applications',
#    'Netw Comput Appl'],
#   'issn': nan,
#   'url': 'http://www.ieee-nca.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'ieee international symposium network computing application'},
#  'nca': {'Index': 81,
#   'raw_name': 'NCA',
#   'id': 'f3fc2b06-d105-40f5-a248-64cf28379e9c',
#   'name': 'IEEE International Symposium on Network Computing and Applications',
#   'type': 'conference',
#   'alternate_names': ['NCA',
#    'IEEE Int Symp Netw Comput Appl',
#    'Network Computing and Applications',
#    'Netw Comput Appl'],
#   'issn': nan,
#   'url': 'http://www.ieee-nca.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'nca'},
#  'ieee int symp netw comput appl': {'Index': 82,
#   'raw_name': 'IEEE Int Symp Netw Comput Appl',
#   'id': 'f3fc2b06-d105-40f5-a248-64cf28379e9c',
#   'name': 'IEEE International Symposium on Network Computing and Applications',
#   'type': 'conference',
#   'alternate_names': ['NCA',
#    'IEEE Int Symp Netw Comput Appl',
#    'Network Computing and Applications',
#    'Netw Comput Appl'],
#   'issn': nan,
#   'url': 'http://www.ieee-nca.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'ieee int symp netw comput appl'},
#  'network computing application': {'Index': 83,
#   'raw_name': 'Network Computing and Applications',
#   'id': 'f3fc2b06-d105-40f5-a248-64cf28379e9c',
#   'name': 'IEEE International Symposium on Network Computing and Applications',
#   'type': 'conference',
#   'alternate_names': ['NCA',
#    'IEEE Int Symp Netw Comput Appl',
#    'Network Computing and Applications',
#    'Netw Comput Appl'],
#   'issn': nan,
#   'url': 'http://www.ieee-nca.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'network computing application'},
#  'netw comput appl': {'Index': 84,
#   'raw_name': 'Netw Comput Appl',
#   'id': 'f3fc2b06-d105-40f5-a248-64cf28379e9c',
#   'name': 'IEEE International Symposium on Network Computing and Applications',
#   'type': 'conference',
#   'alternate_names': ['NCA',
#    'IEEE Int Symp Netw Comput Appl',
#    'Network Computing and Applications',
#    'Netw Comput Appl'],
#   'issn': nan,
#   'url': 'http://www.ieee-nca.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'netw comput appl'},
#  'web conference': {'Index': 85,
#   'raw_name': 'The Web Conference',
#   'id': 'e07422f9-c065-40c3-a37b-75e98dce79fe',
#   'name': 'The Web Conference',
#   'type': 'conference',
#   'alternate_names': ['Web Conf', 'WWW'],
#   'issn': nan,
#   'url': 'http://www.iw3c2.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'web conference'},
#  'web conf': {'Index': 86,
#   'raw_name': 'Web Conf',
#   'id': 'e07422f9-c065-40c3-a37b-75e98dce79fe',
#   'name': 'The Web Conference',
#   'type': 'conference',
#   'alternate_names': ['Web Conf', 'WWW'],
#   'issn': nan,
#   'url': 'http://www.iw3c2.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'web conf'},
#  'www': {'Index': 87,
#   'raw_name': 'WWW',
#   'id': 'e07422f9-c065-40c3-a37b-75e98dce79fe',
#   'name': 'The Web Conference',
#   'type': 'conference',
#   'alternate_names': ['Web Conf', 'WWW'],
#   'issn': nan,
#   'url': 'http://www.iw3c2.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'www'},
#  'file storage technology': {'Index': 88,
#   'raw_name': 'File and Storage Technologies',
#   'id': '2a7ac430-c70b-4147-b72a-237f8cba9f27',
#   'name': 'USENIX Conference on File and Storage Technologies',
#   'type': 'conference',
#   'alternate_names': ['File Storage Technol',
#    'Form Asp Secur Trust',
#    'USENIX Conf File Storage Technol',
#    'FAST',
#    'File and Storage Technologies',
#    'Formal Aspects in Security and Trust'],
#   'issn': nan,
#   'url': 'http://www.wikicfp.com/cfp/program?id=1011',
#   'alternate_urls': ['http://www.dsi.unive.it/IFIPWG1_7/index.html'],
#   'alternate_issns': nan,
#   'clean_name': 'file storage technology'},
#  'ieee transaction affective computing': {'Index': 89,
#   'raw_name': 'IEEE Transactions on Affective Computing',
#   'id': 'a88e2a6c-903f-42e1-8dfc-f2547e32020a',
#   'name': 'IEEE Transactions on Affective Computing',
#   'type': 'journal',
#   'alternate_names': ['IEEE Trans Affect Comput'],
#   'issn': '1949-3045',
#   'url': 'https://ieeexplore.ieee.org/document/7160715/',
#   'alternate_urls': ['http://ieeexplore.ieee.org/servlet/opac?punumber=5165369'],
#   'alternate_issns': nan,
#   'clean_name': 'ieee transaction affective computing'},
#  'ieee trans affect comput': {'Index': 90,
#   'raw_name': 'IEEE Trans Affect Comput',
#   'id': 'a88e2a6c-903f-42e1-8dfc-f2547e32020a',
#   'name': 'IEEE Transactions on Affective Computing',
#   'type': 'journal',
#   'alternate_names': ['IEEE Trans Affect Comput'],
#   'issn': '1949-3045',
#   'url': 'https://ieeexplore.ieee.org/document/7160715/',
#   'alternate_urls': ['http://ieeexplore.ieee.org/servlet/opac?punumber=5165369'],
#   'alternate_issns': nan,
#   'clean_name': 'ieee trans affect comput'},
#  'logic computer science': {'Index': 91,
#   'raw_name': 'Logic in Computer Science',
#   'id': '3673dec6-881d-437a-8c5d-710b0e94690c',
#   'name': 'Logic in Computer Science',
#   'type': 'conference',
#   'alternate_names': ['LICS', 'Log Comput Sci'],
#   'issn': '1043-6871',
#   'url': 'http://ieeexplore.ieee.org/xpl/conhome.jsp?punumber=1000420',
#   'alternate_urls': ['http://www.wikicfp.com/cfp/program?id=1959'],
#   'alternate_issns': nan,
#   'clean_name': 'logic computer science'},
#  'lics': {'Index': 92,
#   'raw_name': 'LICS',
#   'id': '3673dec6-881d-437a-8c5d-710b0e94690c',
#   'name': 'Logic in Computer Science',
#   'type': 'conference',
#   'alternate_names': ['LICS', 'Log Comput Sci'],
#   'issn': '1043-6871',
#   'url': 'http://ieeexplore.ieee.org/xpl/conhome.jsp?punumber=1000420',
#   'alternate_urls': ['http://www.wikicfp.com/cfp/program?id=1959'],
#   'alternate_issns': nan,
#   'clean_name': 'lics'},
#  'log comput sci': {'Index': 93,
#   'raw_name': 'Log Comput Sci',
#   'id': '3673dec6-881d-437a-8c5d-710b0e94690c',
#   'name': 'Logic in Computer Science',
#   'type': 'conference',
#   'alternate_names': ['LICS', 'Log Comput Sci'],
#   'issn': '1043-6871',
#   'url': 'http://ieeexplore.ieee.org/xpl/conhome.jsp?punumber=1000420',
#   'alternate_urls': ['http://www.wikicfp.com/cfp/program?id=1959'],
#   'alternate_issns': nan,
#   'clean_name': 'log comput sci'},
#  'international conference communication computing': {'Index': 94,
#   'raw_name': 'International Conference on Communications in Computing',
#   'id': 'cb55f70b-f8f9-4ae0-8b67-0f0105672b4b',
#   'name': 'International Conference on Communications in Computing',
#   'type': 'conference',
#   'alternate_names': ['Color Imaging Conf',
#    'International Conference on Collaboration and Internet Computing',
#    'CIC',
#    'CDMA Int Conf',
#    'CDMA International Conference',
#    'Int Conf Commun Comput',
#    'Int Conf Collab Internet Comput',
#    'Color Imaging Conference'],
#   'issn': nan,
#   'url': 'http://www.imaging.org/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'international conference communication computing'},
#  'color imaging conf': {'Index': 95,
#   'raw_name': 'Color Imaging Conf',
#   'id': 'cb55f70b-f8f9-4ae0-8b67-0f0105672b4b',
#   'name': 'International Conference on Communications in Computing',
#   'type': 'conference',
#   'alternate_names': ['Color Imaging Conf',
# ...
#   'issn': '2162-4704',
#   'url': 'http://ieeexplore.ieee.org/xpl/conhome.jsp?punumber=1000352',
#   'alternate_urls': nan,
#   'alternate_issns': ['2379-9633'],
#   'clean_name': 'iecon'},
#  'conf ind electron soc': {'Index': 1058,
#   'raw_name': 'Conf Ind Electron Soc',
#   'id': '625842ea-b2ac-4832-aa41-6bd142cfc9d9',
#   'name': 'Annual Conference of the IEEE Industrial Electronics Society',
#   'type': 'conference',
#   'alternate_names': ['Conference of the Industrial Electronics Society',
#    'IECON',
#    'Conf Ind Electron Soc',
#    'Annu Conf IEEE Ind Electron Soc'],
#   'issn': '2162-4704',
#   'url': 'http://ieeexplore.ieee.org/xpl/conhome.jsp?punumber=1000352',
#   'alternate_urls': nan,
#   'alternate_issns': ['2379-9633'],
#   'clean_name': 'conf ind electron soc'},
#  'annu conf ieee ind electron soc': {'Index': 1059,
#   'raw_name': 'Annu Conf IEEE Ind Electron Soc',
#   'id': '625842ea-b2ac-4832-aa41-6bd142cfc9d9',
#   'name': 'Annual Conference of the IEEE Industrial Electronics Society',
#   'type': 'conference',
#   'alternate_names': ['Conference of the Industrial Electronics Society',
#    'IECON',
#    'Conf Ind Electron Soc',
#    'Annu Conf IEEE Ind Electron Soc'],
#   'issn': '2162-4704',
#   'url': 'http://ieeexplore.ieee.org/xpl/conhome.jsp?punumber=1000352',
#   'alternate_urls': nan,
#   'alternate_issns': ['2379-9633'],
#   'clean_name': 'annu conf ieee ind electron soc'},
#  'ieee international conference distributed computing system': {'Index': 1060,
#   'raw_name': 'IEEE International Conference on Distributed Computing Systems',
#   'id': 'ffe5bb5c-04ed-488e-985d-d3a7b39542cf',
#   'name': 'IEEE International Conference on Distributed Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['International Conference on Distributed Computing Systems',
#    'IEEE Int Conf Distrib Comput Syst',
#    'Int Conf Device Circuit Syst',
#    'ICDCS',
#    'Int Conf Distrib Comput Syst',
#    'International Conference on Devices, Circuits and Systems'],
#   'issn': nan,
#   'url': 'https://ieeexplore.ieee.org/xpl/conhome/1000213/all-proceedings',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'ieee international conference distributed computing system'},
#  'international conference distributed computing system': {'Index': 1061,
#   'raw_name': 'International Conference on Distributed Computing Systems',
#   'id': 'ffe5bb5c-04ed-488e-985d-d3a7b39542cf',
#   'name': 'IEEE International Conference on Distributed Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['International Conference on Distributed Computing Systems',
#    'IEEE Int Conf Distrib Comput Syst',
#    'Int Conf Device Circuit Syst',
#    'ICDCS',
#    'Int Conf Distrib Comput Syst',
#    'International Conference on Devices, Circuits and Systems'],
#   'issn': nan,
#   'url': 'https://ieeexplore.ieee.org/xpl/conhome/1000213/all-proceedings',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'international conference distributed computing system'},
#  'ieee int conf distrib comput syst': {'Index': 1062,
#   'raw_name': 'IEEE Int Conf Distrib Comput Syst',
#   'id': 'ffe5bb5c-04ed-488e-985d-d3a7b39542cf',
#   'name': 'IEEE International Conference on Distributed Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['International Conference on Distributed Computing Systems',
#    'IEEE Int Conf Distrib Comput Syst',
#    'Int Conf Device Circuit Syst',
#    'ICDCS',
#    'Int Conf Distrib Comput Syst',
#    'International Conference on Devices, Circuits and Systems'],
#   'issn': nan,
#   'url': 'https://ieeexplore.ieee.org/xpl/conhome/1000213/all-proceedings',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'ieee int conf distrib comput syst'},
#  'int conf device circuit syst': {'Index': 1063,
#   'raw_name': 'Int Conf Device Circuit Syst',
#   'id': 'ffe5bb5c-04ed-488e-985d-d3a7b39542cf',
#   'name': 'IEEE International Conference on Distributed Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['International Conference on Distributed Computing Systems',
#    'IEEE Int Conf Distrib Comput Syst',
#    'Int Conf Device Circuit Syst',
#    'ICDCS',
#    'Int Conf Distrib Comput Syst',
#    'International Conference on Devices, Circuits and Systems'],
#   'issn': nan,
#   'url': 'https://ieeexplore.ieee.org/xpl/conhome/1000213/all-proceedings',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'int conf device circuit syst'},
#  'icdcs': {'Index': 1064,
#   'raw_name': 'ICDCS',
#   'id': 'ffe5bb5c-04ed-488e-985d-d3a7b39542cf',
#   'name': 'IEEE International Conference on Distributed Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['International Conference on Distributed Computing Systems',
#    'IEEE Int Conf Distrib Comput Syst',
#    'Int Conf Device Circuit Syst',
#    'ICDCS',
#    'Int Conf Distrib Comput Syst',
#    'International Conference on Devices, Circuits and Systems'],
#   'issn': nan,
#   'url': 'https://ieeexplore.ieee.org/xpl/conhome/1000213/all-proceedings',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'icdcs'},
#  'int conf distrib comput syst': {'Index': 1065,
#   'raw_name': 'Int Conf Distrib Comput Syst',
#   'id': 'ffe5bb5c-04ed-488e-985d-d3a7b39542cf',
#   'name': 'IEEE International Conference on Distributed Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['International Conference on Distributed Computing Systems',
#    'IEEE Int Conf Distrib Comput Syst',
#    'Int Conf Device Circuit Syst',
#    'ICDCS',
#    'Int Conf Distrib Comput Syst',
#    'International Conference on Devices, Circuits and Systems'],
#   'issn': nan,
#   'url': 'https://ieeexplore.ieee.org/xpl/conhome/1000213/all-proceedings',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'int conf distrib comput syst'},
#  'international conference device circuit system': {'Index': 1066,
#   'raw_name': 'International Conference on Devices, Circuits and Systems',
#   'id': 'ffe5bb5c-04ed-488e-985d-d3a7b39542cf',
#   'name': 'IEEE International Conference on Distributed Computing Systems',
#   'type': 'conference',
#   'alternate_names': ['International Conference on Distributed Computing Systems',
#    'IEEE Int Conf Distrib Comput Syst',
#    'Int Conf Device Circuit Syst',
#    'ICDCS',
#    'Int Conf Distrib Comput Syst',
#    'International Conference on Devices, Circuits and Systems'],
#   'issn': nan,
#   'url': 'https://ieeexplore.ieee.org/xpl/conhome/1000213/all-proceedings',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'international conference device circuit system'},
#  'formal aspect computing': {'Index': 1067,
#   'raw_name': 'Formal Aspects of Computing',
#   'id': '18571b83-47ca-4d90-9e2c-736893f81958',
#   'name': 'Formal Aspects of Computing',
#   'type': 'journal',
#   'alternate_names': ['Form Asp Comput'],
#   'issn': '0934-5043',
#   'url': 'https://www.springer.com/journal/00165/',
#   'alternate_urls': ['http://www.springer.com/journal/00165/',
#    'https://link.springer.com/journal/165'],
#   'alternate_issns': nan,
#   'clean_name': 'formal aspect computing'},
#  'form asp comput': {'Index': 1068,
#   'raw_name': 'Form Asp Comput',
#   'id': '18571b83-47ca-4d90-9e2c-736893f81958',
#   'name': 'Formal Aspects of Computing',
#   'type': 'journal',
#   'alternate_names': ['Form Asp Comput'],
#   'issn': '0934-5043',
#   'url': 'https://www.springer.com/journal/00165/',
#   'alternate_urls': ['http://www.springer.com/journal/00165/',
#    'https://link.springer.com/journal/165'],
#   'alternate_issns': nan,
#   'clean_name': 'form asp comput'},
#  'future generation computer system': {'Index': 1069,
#   'raw_name': 'Future generations computer systems',
#   'id': 'e3e1f91c-fe26-4f67-8d15-f7acd8abdf42',
#   'name': 'Future generations computer systems',
#   'type': 'journal',
#   'alternate_names': ['Future gener comput syst',
#    'Future Generation Computer Systems',
#    'Future Gener Comput Syst'],
#   'issn': '0167-739X',
#   'url': 'http://www.elsevier.com/wps/find/journaleditorialboard.cws_home/505611/editorialboard',
#   'alternate_urls': ['https://www.journals.elsevier.com/future-generation-computer-systems',
#    'http://www.sciencedirect.com/science/journal/0167739X'],
#   'alternate_issns': nan,
#   'clean_name': 'future generation computer system'},
#  'future gener comput syst': {'Index': 1070,
#   'raw_name': 'Future gener comput syst',
#   'id': 'e3e1f91c-fe26-4f67-8d15-f7acd8abdf42',
#   'name': 'Future generations computer systems',
#   'type': 'journal',
#   'alternate_names': ['Future gener comput syst',
#    'Future Generation Computer Systems',
#    'Future Gener Comput Syst'],
#   'issn': '0167-739X',
#   'url': 'http://www.elsevier.com/wps/find/journaleditorialboard.cws_home/505611/editorialboard',
#   'alternate_urls': ['https://www.journals.elsevier.com/future-generation-computer-systems',
#    'http://www.sciencedirect.com/science/journal/0167739X'],
#   'alternate_issns': nan,
#   'clean_name': 'future gener comput syst'},
#  'chinese chemical letter': {'Index': 1073,
#   'raw_name': 'Chinese Chemical Letters',
#   'id': '1b60e44b-dc29-4a1b-b711-f0d70316805c',
#   'name': 'Chinese Chemical Letters',
#   'type': 'journal',
#   'alternate_names': ['Chin Chem Lett'],
#   'issn': '1001-8417',
#   'url': 'https://www.journals.elsevier.com/chinese-chemical-letters/',
#   'alternate_urls': ['http://www.sciencedirect.com/science/journal/10018417'],
#   'alternate_issns': nan,
#   'clean_name': 'chinese chemical letter'},
#  'chin chem lett': {'Index': 1074,
#   'raw_name': 'Chin Chem Lett',
#   'id': '1b60e44b-dc29-4a1b-b711-f0d70316805c',
#   'name': 'Chinese Chemical Letters',
#   'type': 'journal',
#   'alternate_names': ['Chin Chem Lett'],
#   'issn': '1001-8417',
#   'url': 'https://www.journals.elsevier.com/chinese-chemical-letters/',
#   'alternate_urls': ['http://www.sciencedirect.com/science/journal/10018417'],
#   'alternate_issns': nan,
#   'clean_name': 'chin chem lett'},
#  'journal personality social psychology': {'Index': 1075,
#   'raw_name': 'Journal of Personality and Social Psychology',
#   'id': 'dc42ed9c-43ca-4994-b7c6-6321b95442a1',
#   'name': 'Journal of Personality and Social Psychology',
#   'type': 'journal',
#   'alternate_names': ['J Personal Soc Psychol'],
#   'issn': '0022-3514',
#   'url': 'http://www.apa.org/journals/psp.html',
#   'alternate_urls': ['https://www.apa.org/pubs/journals/psp/',
#    'http://www.apa.org/pubs/journals/psp/',
#    'http://content.apa.org/journals/psp'],
#   'alternate_issns': nan,
#   'clean_name': 'journal personality social psychology'},
#  'j personal soc psychol': {'Index': 1076,
#   'raw_name': 'J Personal Soc Psychol',
#   'id': 'dc42ed9c-43ca-4994-b7c6-6321b95442a1',
#   'name': 'Journal of Personality and Social Psychology',
#   'type': 'journal',
#   'alternate_names': ['J Personal Soc Psychol'],
#   'issn': '0022-3514',
#   'url': 'http://www.apa.org/journals/psp.html',
#   'alternate_urls': ['https://www.apa.org/pubs/journals/psp/',
#    'http://www.apa.org/pubs/journals/psp/',
#    'http://content.apa.org/journals/psp'],
#   'alternate_issns': nan,
#   'clean_name': 'j personal soc psychol'},
#  'computational particle mechanic': {'Index': 1077,
#   'raw_name': 'Computational Particle Mechanics',
#   'id': 'a53f043d-7d14-4863-9b4a-bec47b46b0c4',
#   'name': 'Computational Particle Mechanics',
#   'type': 'journal',
#   'alternate_names': ['Comput part mech',
#    'Computational particle mechanics',
#    'Comput Part Mech'],
#   'issn': '2196-4386',
#   'url': 'https://link.springer.com/journal/40571',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'computational particle mechanic'},
#  'comput part mech': {'Index': 1078,
#   'raw_name': 'Comput part mech',
#   'id': 'a53f043d-7d14-4863-9b4a-bec47b46b0c4',
#   'name': 'Computational Particle Mechanics',
#   'type': 'journal',
#   'alternate_names': ['Comput part mech',
#    'Computational particle mechanics',
#    'Comput Part Mech'],
#   'issn': '2196-4386',
#   'url': 'https://link.springer.com/journal/40571',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'comput part mech'},
#  'acm symposium access control model technology': {'Index': 1081,
#   'raw_name': 'ACM Symposium on Access Control Models and Technologies',
#   'id': '4e1cc57b-e4fd-47df-b3f4-2cd6289360e7',
#   'name': 'ACM Symposium on Access Control Models and Technologies',
#   'type': 'conference',
#   'alternate_names': ['SACMAT',
#    'Symposium on Access Control Models and Technologies',
#    'Symp Access Control Model Technol',
#    'ACM Symp Access Control Model Technol'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigsac/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'acm symposium access control model technology'},
#  'sacmat': {'Index': 1082,
#   'raw_name': 'SACMAT',
#   'id': '4e1cc57b-e4fd-47df-b3f4-2cd6289360e7',
#   'name': 'ACM Symposium on Access Control Models and Technologies',
#   'type': 'conference',
#   'alternate_names': ['SACMAT',
#    'Symposium on Access Control Models and Technologies',
#    'Symp Access Control Model Technol',
#    'ACM Symp Access Control Model Technol'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigsac/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'sacmat'},
#  'symposium access control model technology': {'Index': 1083,
#   'raw_name': 'Symposium on Access Control Models and Technologies',
#   'id': '4e1cc57b-e4fd-47df-b3f4-2cd6289360e7',
#   'name': 'ACM Symposium on Access Control Models and Technologies',
#   'type': 'conference',
#   'alternate_names': ['SACMAT',
#    'Symposium on Access Control Models and Technologies',
#    'Symp Access Control Model Technol',
#    'ACM Symp Access Control Model Technol'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigsac/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'symposium access control model technology'},
#  'symp access control model technol': {'Index': 1084,
#   'raw_name': 'Symp Access Control Model Technol',
#   'id': '4e1cc57b-e4fd-47df-b3f4-2cd6289360e7',
#   'name': 'ACM Symposium on Access Control Models and Technologies',
#   'type': 'conference',
#   'alternate_names': ['SACMAT',
#    'Symposium on Access Control Models and Technologies',
#    'Symp Access Control Model Technol',
#    'ACM Symp Access Control Model Technol'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigsac/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'symp access control model technol'},
#  'acm symp access control model technol': {'Index': 1085,
#   'raw_name': 'ACM Symp Access Control Model Technol',
#   'id': '4e1cc57b-e4fd-47df-b3f4-2cd6289360e7',
#   'name': 'ACM Symposium on Access Control Models and Technologies',
#   'type': 'conference',
#   'alternate_names': ['SACMAT',
#    'Symposium on Access Control Models and Technologies',
#    'Symp Access Control Model Technol',
#    'ACM Symp Access Control Model Technol'],
#   'issn': nan,
#   'url': 'http://www.acm.org/sigsac/',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'acm symp access control model technol'},
#  'informatik spektrum': {'Index': 1086,
#   'raw_name': 'Informatik-Spektrum',
#   'id': '518d38cf-179f-480b-b32a-c9d4e6bba46e',
#   'name': 'Informatik-Spektrum',
#   'type': 'journal',
#   'alternate_names': ['Informatik Spektrum', 'Inform Spektrum'],
#   'issn': '0170-6012',
#   'url': 'https://link.springer.com/journal/287',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'informatik spektrum'},
#  'inform spektrum': {'Index': 1088,
#   'raw_name': 'Inform Spektrum',
#   'id': '518d38cf-179f-480b-b32a-c9d4e6bba46e',
#   'name': 'Informatik-Spektrum',
#   'type': 'journal',
#   'alternate_names': ['Informatik Spektrum', 'Inform Spektrum'],
#   'issn': '0170-6012',
#   'url': 'https://link.springer.com/journal/287',
#   'alternate_urls': nan,
#   'alternate_issns': nan,
#   'clean_name': 'inform spektrum'},
#  'resonance': {'Index': 1089,
#   'raw_name': 'Resonance',
#   'id': '814e9fad-f467-445d-94be-9839ee17ddd1',
#   'name': 'Resonance',
#   'type': 'journal',
#   'alternate_names': nan,
#   'issn': '2688-867X',
#   'url': 'http://www.springer.com/',
#   'alternate_urls': ['http://link.springer.com/journal/12045',
#    'https://link.springer.com/journal/12045'],
#   'alternate_issns': ['0973-712X', '0971-8044'],
#   'clean_name': 'resonance'},
#  ...}

# %%
verified_venues = {}
pending_venues = []
for k, v in venue_info.items():
    if type(v) == dict:
        verified_venues[k] = v
        continue
    cleaned_name = clean_venue_name(k)
    if k == "2009 IEEE 31st International Conference on Software Engineering":
        print(cleaned_name, cleaned_name in cleaned_name_to_info)
    if cleaned_name in cleaned_name_to_info:
        verified_venues[k] = cleaned_name_to_info[cleaned_name]
    else:
        pending_venues.append(k)
# Out:
# ieee international conference software engineering False

# %%
len(valid_venues), len(verified_venues), len(pending_venues)
# Out:
# (5915, 6011, 1268)

# %%
venue_names = list({clean_venue_name(v) for v in venue_info.keys()})
venue_names[2001]
# Out:
# 'cardis'

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.encode(venue_names, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/213 [00:00<?, ?it/s]

# %%
venue_embeddings = {}
for i, venue in enumerate(venue_names):
    venue_embeddings[venue] = embeddings[i]

# %%
from sentence_transformers import util


def get_similarity(v1, v2):
    v1 = clean_venue_name(v1)
    print(v1)
    v2 = clean_venue_name(v2)
    print(v2)
    v1 = venue_embeddings[v1]
    v2 = venue_embeddings[v2]
    return util.pytorch_cos_sim(v1, v2).item()


def find_most_similar_venue(venue: str):
    venue = clean_venue_name(venue)
    embed_venue = venue_embeddings[venue]
    cosine_sim = util.pytorch_cos_sim(embed_venue, embeddings)[0]
    input_index = venue_names.index(venue)
    cosine_sim[input_index] = -1
    most_similar_venues = []
    if len(venue.split()) > 5:
        threshold = 0.87
    else:
        threshold = 0.9
    for i, score in enumerate(cosine_sim):
        if score >= threshold:
            most_similar_venues.append((venue_names[i], score.item()))
    most_similar_venues.sort(key=lambda x: x[1], reverse=True)
    return most_similar_venues

# %%
aliases = {}
cluster_nb = 0
for venue in tqdm(pending_venues):
    most_similar_venues = find_most_similar_venue(venue)
    if len(most_similar_venues) == 0:
        continue
    cid = None
    if venue in aliases:
        cid = aliases[venue]
    else:
        for sv, _ in most_similar_venues:
            if sv in aliases:
                cid = aliases[sv]
                break
    if cid is None:
        cid = cluster_nb
        cluster_nb += 1
    aliases[venue] = cid
    for sv, _ in most_similar_venues:
        aliases[sv] = cid
print("Found {} clusters".format(cluster_nb))
# Out:
# 100%|██████████| 1277/1277 [00:40<00:00, 31.39it/s]
# Found 261 clusters

# %%
import pandas as pd

alias_df = pd.DataFrame(aliases.items(), columns=["venue", "cluster"])
alias_df = alias_df.groupby("cluster").agg(set)
alias_df.to_json("venue_aliases.json", indent=2, orient="records")
alias_df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                            venue
# cluster
# 0                                                                                     {ieee transaction industrial electronics, ieee transaction industrial informatics, ieee transaction circuit system, ieee transaction computer, ieee transaction power system, ieee transaction consumer electronics, IEEE Transactions on Circuits and Systems, IEEE transactions on industrial electronics (1982. Print)}
# 1        {european journal combinatorics, journal combinatorial theory, electronic journal combinatorics, journal combinatorial optimization, journal combinatorial theory series b, European journal of combinatorics (Print), Journal of combinatorial theory, Journal of Combinatorial Designs, Journal of Combinatorial Theory, Series B, journal combinatorial design, journal combinatorial theory series}
# 2                                                                                                                                                                                   {international journal new computer architecture application, International journal of computer applications, international journal applied information system, international journal advanced computer science application}
# 3                                                                                                                                                                                                                                                                                                                                                                                     {acm se, ACM '58, ACM '59}
# 4                                                                                                                                                                                                                                                                                                                                                                                   {Rep4NLP@ACL, replnlp @ acl}

# %%
get_similarity(
    "2009 IEEE 31st International Conference on Software Engineering",
    "International Conference on Software Engineering",
)
# Out:
# ieee international conference software engineering
# international conference software engineering
# 0.8715152740478516

# %%
find_most_similar_venue(
    "2009 IEEE 31st International Conference on Software Engineering"
)
# Out:
# []

# %%
test = "Proceedings of the 2001 IEEE Computer Society Conference on Computer Vision and Pattern Recognition. CVPR 2001"
test = clean_venue_name(test)
aliases[test]
# Out:
# 7

# %%
[v for v, c in aliases.items() if c == 28]
# Out:
# ['Journal of the Royal Statistical Society Series B: Statistical Methodology',
#  'journal royal statistical society series c']

# %%
with open("checked_aliases.json", "r") as f:
    checked_aliases = json.load(f)
checked_aliases
# Out:
# [{'venue': ['ieee annual symposium foundation computer science',
#    '30th Annual Symposium on Foundations of Computer Science',
#    '40th Annual Symposium on Foundations of Computer Science (Cat. No.99CB37039)',
#    '28th Annual Symposium on Foundations of Computer Science (sfcs 1987)',
#    '[ ] annual symposium foundation computer science',
#    '18th Annual Symposium on Foundations of Computer Science (sfcs 1977)',
#    '17th Annual Symposium on Foundations of Computer Science (sfcs 1976)',
#    '20th Annual Symposium on Foundations of Computer Science (sfcs 1979)',
#    '21st Annual Symposium on Foundations of Computer Science (sfcs 1980)',
#    '26th Annual Symposium on Foundations of Computer Science (sfcs 1985)',
#    'Proceedings 39th Annual Symposium on Foundations of Computer Science (Cat. No.98CB36280)',
#    '27th Annual Symposium on Foundations of Computer Science (sfcs 1986)',
#    '23rd Annual Symposium on Foundations of Computer Science (sfcs 1982)']},
#  {'venue': ['lics',
#    '[1992] Proceedings of the Seventh Annual IEEE Symposium on Logic in Computer Science',
#    'annual ieee symposium logic computer science',
#    '[1990] Proceedings. Fifth Annual IEEE Symposium on Logic in Computer Science']},
#  {'venue': ['ieee annual symposium foundation computer science',
#    'The 43rd Annual IEEE Symposium on Foundations of Computer Science, 2002. Proceedings.']},
#  {'venue': ['Journal of Applied Econometrics',
#    'journal applied econometrics']},
#  {'venue': ['econometrics journal',
#    'Journal of Econometrics',
#    'The Econometrics Journal',
#    'journal econometrics']},
#  {'venue': ['2014 22nd Euromicro International Conference on Parallel, Distributed, and Network-Based Processing',
#    'international euromicro conference parallel distributed network based processing',
#    '2009 17th Euromicro International Conference on Parallel, Distributed and Network-based Processing']},
#  {'venue': ['ieee international conference acoustic speech signal processing',
#    '1996 IEEE International Conference on Acoustics, Speech, and Signal Processing Conference Proceedings',
#    'international conference acoustic speech signal processing']},
#  {'venue': ['ieee transaction system science cybernetics',
#    'ieee transaction system man cybernetics part',
#    'IEEE Transactions on Systems, Man, and Cybernetics - Part A: Systems and Humans',
#    'ieee transaction system man cybernetics part b',
#    'ieee transaction system man cybernetics part c',
#    'IEEE Transactions on Systems, Man, and Cybernetics, Part B (Cybernetics)',
#    'ieee transaction cybernetics',
#    'ieee transaction system man cybernetics']},
#  {'venue': ['2021 IEEE/CVF International Conference on Computer Vision Workshops (ICCVW)',
#    '2013 IEEE International Conference on Computer Vision Workshops',
#    'ieee cvf international conference computer vision workshop',
#    '2019 IEEE/CVF International Conference on Computer Vision Workshop (ICCVW)',
#    'ieee cvf international conference computer vision',
#    'ieee international conference computer vision',
#    '2017 IEEE International Conference on Computer Vision Workshops (ICCVW)']},
#  {'venue': ['2012 IEEE Conference on Computer Vision and Pattern Recognition',
#    '2013 IEEE Conference on Computer Vision and Pattern Recognition Workshops',
#    '2007 IEEE Conference on Computer Vision and Pattern Recognition',
#    '2014 IEEE Conference on Computer Vision and Pattern Recognition Workshops',
#    '2017 IEEE Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    'computer vision pattern recognition',
#    '2016 IEEE Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    'Proceedings. 1999 IEEE Computer Society Conference on Computer Vision and Pattern Recognition (Cat. No PR00149)',
#    'ieee conference computer vision pattern recognition workshop',
#    'ieee computer society conference computer vision pattern recognition workshop',
#    '2018 IEEE/CVF Conference on Computer Vision and Pattern Recognition',
#    'ieee cvf conference computer vision pattern recognition',
#    '2014 IEEE Conference on Computer Vision and Pattern Recognition',
#    'ieee computer society conference computer vision pattern recognition cvpr',
#    '2015 IEEE Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    '2010 IEEE Computer Society Conference on Computer Vision and Pattern Recognition',
#    '1994 Proceedings of IEEE Conference on Computer Vision and Pattern Recognition',
#    '2018 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    '2022 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    'ieee conference computer vision pattern recognition',
#    'Proceedings of IEEE Computer Society Conference on Computer Vision and Pattern Recognition',
#    'Proceedings of the 2001 IEEE Computer Society Conference on Computer Vision and Pattern Recognition. CVPR 2001',
#    '2020 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    '2023 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    'ieee computer society conference computer vision pattern recognition',
#    '2013 IEEE Conference on Computer Vision and Pattern Recognition',
#    '2008 IEEE Conference on Computer Vision and Pattern Recognition',
#    '2019 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)']},
#  {'venue': ['international ieee conference intelligent transportation system',
#    '13th International IEEE Conference on Intelligent Transportation Systems',
#    'ieee international conference intelligent transportation system',
#    'international conference intelligent transportation system',
#    '2012 15th International IEEE Conference on Intelligent Transportation Systems',
#    'Proceedings of the 2003 IEEE International Conference on Intelligent Transportation Systems']},
#  {'venue': ['springer mathematics statistic',
#    'Springer Proceedings in Mathematics &amp; Statistics']},
#  {'venue': ['annual ieee international conference pervasive computing communication',
#    '2012 IEEE International Conference on Pervasive Computing and Communications Workshops',
#    'ieee international conference pervasive computing communication']},
#  {'venue': ['The Canadian Journal of Statistics/La revue canadienne de statistique',
#    'canadian journal statistic revue canadienne de statistique']},
#  {'venue': ['international symposium industrial electronics',
#    '2012 IEEE International Symposium on Industrial Electronics',
#    '2009 IEEE International Symposium on Industrial Electronics']},
#  {'venue': ['international conference computing information technology',
#    '2010 10th IEEE International Conference on Computer and Information Technology',
#    'ieee conference information communication technology']},
#  {'venue': ['ieee international symposium parallel distributed processing',
#    'Proceedings of 1993 5th IEEE Symposium on Parallel and Distributed Processing',
#    'ieee international parallel distributed processing symposium',
#    'ieee international parallel distributed processing symposium workshop phd forum',
#    '2013 IEEE 27th International Symposium on Parallel and Distributed Processing',
#    'ieee international symposium parallel distributed processing workshop phd forum',
#    '2012 IEEE 26th International Parallel and Distributed Processing Symposium Workshops & PhD Forum',
#    'ieee symposium parallel distributed processing',
#    '2008 IEEE International Symposium on Parallel and Distributed Processing',
#    'international parallel distributed processing symposium']},
#  {'venue': ['international conference computational science',
#    '2009 International Conference on Computational Science and Engineering']},
#  {'venue': ['international conference software engineering research application',
#    '2008 Sixth International Conference on Software Engineering Research, Management and Applications']},
#  {'venue': ['Journal of Geophysical Research: Solid Earth',
#    'Journal of Geophysical Research']},
#  {'venue': ['international symposium information theory',
#    '2000 IEEE International Symposium on Information Theory (Cat. No.00CH37060)',
#    '2008 IEEE International Symposium on Information Theory']},
#  {'venue': ['Journal of the Royal Statistical Society Series C: Applied Statistics',
#    'journal royal statistical society series b']},
#  {'venue': ['international conference parallel processing',
#    '2017 46th International Conference on Parallel Processing Workshops (ICPPW)',
#    '2010 39th International Conference on Parallel Processing Workshops']},
#  {'venue': ['SIAM journal on computing (Print)',
#    'siam journal scientific computing']},
#  {'venue': ['Computer-Aided Design', 'computer aided design application']},
#  {'venue': ['european physical journal c',
#    'european physical journal',
#    'The European Physical Journal E : Soft matter',
#    'The European Physical Journal C',
#    'european physical journal e']},
#  {'venue': ['international conference software testing verification validation',
#    '2010 Third International Conference on Software Testing, Verification, and Validation Workshops']},
#  {'venue': ['American Journal of Physics',
#    'journal applied physic',
#    'journal physic',
#    'american journal physic',
#    'Journal of Applied Physics',
#    'Journal of Physics: Materials',
#    'New Journal of Physics',
#    'Journal of Physics: Complexity',
#    'new journal physic']},
#  {'venue': ['Philosophical transactions of the Royal Society of London',
#    'philosophical transaction royal society b']},
#  {'venue': ['journal royal statistical society series c',
#    'Journal of the Royal Statistical Society Series B: Statistical Methodology']},
#  {'venue': ['Mathematical Geosciences',
#    'encyclopedia mathematical geosciences']},
#  {'venue': ['annual international computer software application conference',
#    '2012 IEEE 36th Annual Computer Software and Applications Conference',
#    '2014 IEEE 38th Annual Computer Software and Applications Conference']},
#  {'venue': ['Computer-aided Design and Applications',
#    'computer aided design']},
#  {'venue': ['2019 IEEE International Conference on Cloud Computing Technology and Science (CloudCom)',
#    '4th IEEE International Conference on Cloud Computing Technology and Science Proceedings',
#    'ieee international conference cloud computing']},
#  {'venue': ['annals statistic',
#    'The Annals of Applied Statistics',
#    'annals applied statistic']},
#  {'venue': ['annals mathematical statistic',
#    'Annals of Mathematical Statistics']},
#  {'venue': ['Springer proceedings in mathematics & statistics',
#    'springer mathematics andamp ; statistic']},
#  {'venue': ['2006 International Conference on Intelligent Information Hiding and Multimedia',
#    'international conference intelligent information hiding multimedia signal processing']},
#  {'venue': ['2014 IEEE 26th International Symposium on Computer Architecture and High Performance Computing',
#    'international symposium high performance computer architecture']},
#  {'venue': ['data compression conference dcc',
#    "Proceedings DCC'99 Data Compression Conference (Cat. No. PR00096)",
#    "Proceedings DCC '95 Data Compression Conference",
#    'dcc']},
#  {'venue': ['Proceedings of 37th Conference on Foundations of Computer Science',
#    'international conference foundation computer science',
#    'ieee annual symposium foundation computer science']},
#  {'venue': ['international journal human resource management',
#    'Human Resource Management Journal']},
#  {'venue': ['International Journal of Human Resource Management',
#    'human resource management journal']},
#  {'venue': ['ieee annual symposium foundation computer science',
#    '[Proceedings 1988] 29th Annual Symposium on Foundations of Computer Science',
#    'annual symposium foundation computer science',
#    'Proceedings [1990] 31st Annual Symposium on Foundations of Computer Science']},
#  {'venue': ['international conference document analysis recognition',
#    'ieee international conference document analysis recognition',
#    '2019 International Conference on Document Analysis and Recognition Workshops (ICDARW)']},
#  {'venue': ['oxford university press ebooks',
#    'Cambridge University Press eBooks']},
#  {'venue': ['international conference automated software engineering',
#    '2009 IEEE/ACM International Conference on Automated Software Engineering',
#    '2012 Proceedings of the 27th IEEE/ACM International Conference on Automated Software Engineering']},
#  {'venue': ['Performance evaluation (Print)',
#    'performance evaluation review']},
#  {'venue': ['front neurorobotics', 'Front. Neurorobot.']},
#  {'venue': ['icdt', 'ICDTE']},
#  {'venue': ['2021 IEEE International Conference on Communications Workshops (ICC Workshops)',
#    'ieee international conference communication',
#    'international conference communication']},
#  {'venue': ['international conference communication',
#    'ieee international conference communication workshop',
#    '2017 IEEE International Conference on Communications (ICC)',
#    'ieee international conference computer communication',
#    'ieee conference computer communication',
#    'ieee international conference communication system']},
#  {'venue': ['international conference neural network',
#    'IEEE 1988 International Conference on Neural Networks',
#    'IEEE International Conference on Neural Networks',
#    'ieee international joint conference neural network']},
#  {'venue': ['2010 Fourth International Conference on Genetic and Evolutionary Computing',
#    'annual conference genetic evolutionary computation',
#    'genetic evolutionary computation conference']},
#  {'venue': ['Proceedings of the First IEEE Conference on Evolutionary Computation. IEEE World Congress on Computational Intelligence',
#    'ieee congress evolutionary computation',
#    'ieee international conference evolutionary computation']},
#  {'venue': ['2009 First International Conference on Information Science and Engineering',
#    'international conference information engineering computer science']},
#  {'venue': ['BMC Genomic Data', 'bmc genomics']},
#  {'venue': ['transportation research part b',
#    'Transportation Research Part A: Policy and Practice',
#    'Transportation Research Part C: Emerging Technologies']},
#  {'venue': ['ISPRS Annals of the Photogrammetry, Remote Sensing and Spatial Information Sciences',
#    'isprs journal photogrammetry remote sensing']},
#  {'venue': ['advanced video signal based surveillance',
#    'ieee international conference advanced video signal based surveillance',
#    'Proceedings of the IEEE Conference on Advanced Video and Signal Based Surveillance, 2003.']},
#  {'venue': ['USENIX Annual Technical Conference, General Track',
#    'usenix annual technical conference']},
#  {'venue': ['2012 IEEE 28th International Conference on Data Engineering Workshops',
#    'ieee international conference data engineering']},
#  {'venue': ['2006 IEEE/RSJ International Conference on Intelligent Robots and Systems',
#    '2013 IEEE/RSJ International Conference on Intelligent Robots and Systems',
#    '2011 IEEE/RSJ International Conference on Intelligent Robots and Systems',
#    'ieee rjs international conference intelligent robot system']},
#  {'venue': ['Journal of Banking and Finance',
#    'Journal of Financial Economics',
#    'journal finance']},
#  {'venue': ['2013 SC - International Conference for High Performance Computing, Networking, Storage and Analysis (SC)',
#    'international conference high performance computing networking storage analysis',
#    '2008 SC - International Conference for High Performance Computing, Networking, Storage and Analysis']},
#  {'venue': ['ICASSP-88., International Conference on Acoustics, Speech, and Signal Processing',
#    'ieee international conference acoustic speech signal processing']},
#  {'venue': ['mathematical geosciences',
#    'Encyclopedia of Mathematical Geosciences']},
#  {'venue': ['performance evaluation', 'Performance evaluation review']},
#  {'venue': ['international conference software engineering',
#    '2008 ACM/IEEE 30th International Conference on Software Engineering']},
#  {'venue': ['ieee international conference data mining',
#    '2017 IEEE International Conference on Data Mining Workshops (ICDMW)',
#    '2016 IEEE 16th International Conference on Data Mining Workshops (ICDMW)']},
#  {'venue': ['IEEE Transactions on Acoustics, Speech, and Signal Processing',
#    'ieee transaction audio speech language processing',
#    'ieee transaction speech audio processing']},
#  {'venue': ['annual hawaii international conference system science',
#    '1994 Proceedings of the Twenty-Seventh Hawaii International Conference on System Sciences',
#    'Proceedings of the Thirty-First Hawaii International Conference on System Sciences']},
#  {'venue': ['international conference software maintenance',
#    'Proceedings Conference on Software Maintenance 1992',
#    'conference software maintenance reengineering']},
#  {'venue': ['2005 IEEE Engineering in Medicine and Biology 27th Annual Conference',
#    'annual international conference ieee engineering medicine biology society',
#    'international conference ieee engineering medicine biology society']},
#  {'venue': ['2006 Eighth International Symposium on Symbolic and Numeric Algorithms for Scientific Computing',
#    'symposium symbolic numeric algorithm scientific computing',
#    '2013 15th International Symposium on Symbolic and Numeric Algorithms for Scientific Computing',
#    'symbolic numeric algorithm scientific computing']},
#  {'venue': ['ieee acm international symposium cluster cloud grid computing',
#    '2010 10th IEEE/ACM International Conference on Cluster, Cloud and Grid Computing']},
#  {'venue': ['Proceedings of the 1996 Conference on Parallel Architectures and Compilation Technique',
#    'international conference parallel architecture compilation technique']},
#  {'venue': ['ieee trans neural netw learn syst',
#    'IEEE Trans. Neural Networks Learn. Syst.']},
#  {'venue': ['advanced video signal based surveillance',
#    'ieee conference advanced video signal based surveillance',
#    '2009 Sixth IEEE International Conference on Advanced Video and Signal Based Surveillance']},
#  {'venue': ['ieee international conference acoustic speech signal processing',
#    'icassp international conference acoustic speech signal processing',
#    '1999 IEEE International Conference on Acoustics, Speech, and Signal Processing. Proceedings. ICASSP99 (Cat. No.99CH36258)']},
#  {'venue': ['moon planet', 'Moon and the planets']},
#  {'venue': ['earth moon planet', 'Earth, Moon, and Planets']},
#  {'venue': ['annual meeting ieee industry application society',
#    'ieee industry application society annual meeting',
#    'Conference Record of the 1988 IEEE Industry Applications Society Annual Meeting']},
#  {'venue': ['international conference parallel distributed system',
#    '2022 3rd International Conference on Information Science, Parallel and Distributed Systems (ISPDS)']},
#  {'venue': ['ieee trans syst man cybern part c ( application rev',
#    'IEEE Trans. Syst. Man Cybern. Part A',
#    'ieee trans syst man cybern',
#    'ieee trans syst sci cybern',
#    'ieee int conf syst man cybern']},
#  {'venue': ['ieee ifip international conference software architecture',
#    '2014 IEEE/IFIP Conference on Software Architecture']},
#  {'venue': ['transportation research part',
#    'Transportation Research Part B: Methodological',
#    'transportation research part c']},
#  {'venue': ['2009 IEEE International Conference on Intelligent Computing and Intelligent Systems',
#    'international ieee conference intelligent system']},
#  {'venue': ['Front. Physio.', 'front phys']},
#  {'venue': ['2008 IEEE International Symposium on Modeling, Analysis and Simulation of Computers and Telecommunication Systems',
#    'modeling analysis simulation computer telecommunication system',
#    'ieee acm international symposium modeling analysis simulation computer telecommunication system',
#    'international symposium modeling analysis simulation computer telecommunication system']},
#  {'venue': ['Data Compression Conference, 2004. Proceedings. DCC 2004',
#    'dcc data compression conference',
#    'dcc']},
#  {'venue': ['Proceedings of 1994 IEEE 3rd International Fuzzy Systems Conference',
#    'ieee international conference fuzzy system']},
#  {'venue': ['international symposium computer architecture',
#    'Proceedings of the 20th Annual International Symposium on Computer Architecture']},
#  {'venue': ['international conference computer science application',
#    '2010 Second International Conference on Computer Engineering and Applications']},
#  {'venue': ['2013 IEEE CONFERENCE ON INFORMATION AND COMMUNICATION TECHNOLOGIES',
#    'ieee international conference computer information technology']},
#  {'venue': ['Proceedings Seventh International Symposium on String Processing and Information Retrieval. SPIRE 2000',
#    'symposium string processing information retrieval']},
#  {'venue': ['international conference electrical engineering informatics',
#    '2017 4th International Conference on Electrical Engineering, Computer Science and Informatics (EECSI)']},
#  {'venue': ['Philosophical Transactions of the Royal Society B: Biological Sciences',
#    'philosophical transaction royal society london']},
#  {'venue': ['international conference networking computing',
#    '2010 International Conference on Networking and Information Technology']},
#  {'venue': ['ieee international conference system man cybernetics',
#    '1995 IEEE International Conference on Systems, Man and Cybernetics. Intelligent Systems for the 21st Century']},
#  {'venue': ["Systems Integration '90. Proceedings of the First International Conference on Systems Integration",
#    'international conference system integration']},
#  {'venue': ['2017 IEEE International Conference on Multimedia & Expo Workshops (ICMEW)',
#    'ieee international conference multimedia expo']},
#  {'venue': ['journal geophysical research',
#    'Geophysical Journal International']},
#  {'venue': ['Journal of Applied Meteorology and Climatology',
#    'journal applied meteorology']},
#  {'venue': ['annals applied probability', 'Annals of Probability']},
#  {'venue': ['ieee intelligent vehicle symposium',
#    'Intelligent Vehicle Symposium, 2002. IEEE',
#    'intelligent vehicle symposium']},
#  {'venue': ['2016 IEEE International Conference on Advances in Computer Applications (ICACA)',
#    'ac ieee international conference computer system application']},
#  {'venue': ['Log. Methods Comput. Sci.', 'log comput sci']},
#  {'venue': ['Journal of Combinatorial Theory, Series B',
#    'journal combinatorial theory series']},
#  {'venue': ['Communications in Statistics - Theory and Methods',
#    'communication statistic',
#    'commun stat simul comput']},
#  {'venue': ['j intell robot syst',
#    'intell robot syst',
#    'J. Intell. Robotic Syst.']},
#  {'venue': ['lics',
#    'ieee annual symposium foundation computer science',
#    'annual ieee symposium foundation computer science',
#    '2009 24th Annual IEEE Symposium on Logic In Computer Science',
#    '[ ] annual ieee symposium logic computer science']},
#  {'venue': ['usenix annual technical conference',
#    'USENIX Annual Technical Conference, FREENIX Track']},
#  {'venue': ['AAAI/IAAI', 'iaai']},
#  {'venue': ['international conference intelligent information hiding multimedia',
#    '2009 Fifth International Conference on Intelligent Information Hiding and Multimedia Signal Processing',
#    'information hiding multimedia security']},
#  {'venue': ['AAAI/IAAI, Vol. 1', 'iaai']},
#  {'venue': ['2012 13th ACIS International Conference on Software Engineering, Artificial Intelligence, Networking and Parallel/Distributed Computing',
#    'software engineering artificial intelligence networking parallel distributed computing']},
#  {'venue': ['Proceedings of the 2006 Winter Simulation Conference',
#    'Proceedings of the 2010 Winter Simulation Conference'],
#   'name': 'Proceedings of the Winter Simulation Conference'},
#  {'venue': ['2009 17th Euromicro International Conference on Parallel, Distributed and Network-based Processing',
#    '2014 22nd Euromicro International Conference on Parallel, Distributed, and Network-Based Processing'],
#   'name': 'Euromicro International Conference on Parallel Distributed Network Based Processing'},
#  {'venue': ['2012 IEEE International Symposium on Industrial Electronics',
#    '2009 IEEE International Symposium on Industrial Electronics',
#    'International Symposium on Industrial Electronics']},
#  {'venue': ['SIGSOFT FSE',
#    "SIGSOFT '08/FSE-16",
#    'Foundations of Software Engineering']},
#  {'venue': ['2020 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    '2023 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    '2019 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    '2022 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    '2018 IEEE/CVF Conference on Computer Vision and Pattern Recognition Workshops (CVPRW)',
#    'IEEE Computer Society Conference on Computer Vision and Pattern Recognition workshops']},
#  {'venue': ['Journal of magnetic resonullce',
#    'Journal of magnetic resonullce (San Diego, Calif. 1997 : Print)'],
#   'name': 'Journal of magnetic resonullce'},
#  {'venue': ['2017 25th Mediterranean Conference on Control and Automation (MED)',
#    '2020 28th Mediterranean Conference on Control and Automation (MED)'],
#   'name': 'Mediterranean Conference on Control and Automation'},
#  {'venue': ['WIREs Data. Mining. Knowl. Discov.',
#    'WIREs Data Mining Knowl. Discov.'],
#   'name': 'WIREs Data Mining and Knowledge Discovery'},
#  {'venue': ['Structural Equation Modeling: A Multidisciplinary Journal',
#    'Structural equation modeling : a multidisciplinary journal'],
#   'name': 'Structural Equation Modeling'},
#  {'venue': ["LFP '84", "LFP '92", "LFP '86"],
#   'name': 'Conference on LISP and Functional Programming'},
#  {'venue': ['Proceedings of the 2000 Congress on Evolutionary Computation. CEC00 (Cat. No.00TH8512)',
#    "Proceedings of the 2002 Congress on Evolutionary Computation. CEC'02 (Cat. No.02TH8600)",
#    'IEEE Congress on Evolutionary Computation']},
#  {'venue': ['ML/OCAML', 'ML/OCaml'], 'name': 'OCAML'},
#  {'venue': ['2012 IEEE 12th International Working Conference on Source Code Analysis and Manipulation',
#    '2011 IEEE 11th International Working Conference on Source Code Analysis and Manipulation',
#    '2009 Ninth IEEE International Working Conference on Source Code Analysis and Manipulation'],
#   'name': 'Working Conference on Source Code Analysis and Manipulation'},
#  {'venue': ['2010 IEEE International Conference on Image Processing',
#    '2013 IEEE International Conference on Image Processing',
#    'IEEE International Conference on Image Processing 2005',
#    '2008 15th IEEE International Conference on Image Processing',
#    'International Conference on Image Processing']},
#  {'venue': ['2015 IEEE Security and Privacy Workshops',
#    '2017 IEEE Security and Privacy Workshops (SPW)',
#    '2018 IEEE Security and Privacy Workshops (SPW)'],
#   'name': 'IEEE Security and Privacy Workshops'},
#  {'venue': ['2010 IEEE/IFIP International Conference on Embedded and Ubiquitous Computing',
#    '2008 IEEE/IFIP International Conference on Embedded and Ubiquitous Computing'],
#   'name': 'International Conference on Embedded and Ubiquitous Computing'},
#  {'venue': ['2011 IEEE International Conference on Industrial Technology',
#    '2006 IEEE International Conference on Industrial Technology'],
#   'name': 'IEEE International Conference on Industrial Technology'},
#  {'venue': ["SCG '95",
#    "SCG '01",
#    "SCG '94",
#    "SCG '87",
#    "SCG '03",
#    "SCG '04",
#    "SCG '90",
#    "SCG '88",
#    "SCG '02"],
#   'name': 'Proceedings of the eleventh annual symposium on Computational geometry'},
#  {'venue': ['Journal of magnetic resonance',
#    'Journal of magnetic resonance (San Diego, Calif. 1997 : Print)'],
#   'name': 'Journal of magnetic resonance'},
#  {'venue': ['ieee international conference software engineering',
#    '2008 ACM/IEEE 30th International Conference on Software Engineering',
#    'international conference on software engineering',
#    '2009 IEEE 31st International Conference on Software Engineering']},
#  {'venue': ['Design Automation Conference',
#    '[1992] Proceedings The European Conference on Design Automation',
#    '27th ACM/IEEE Design Automation Conference']},
#  {'venue': ['VS@HLT-NAACL',
#    'TextGraphs@NAACL-HLT',
#    'Mturk@HLT-NAACL',
#    'North American Chapter of the Association for Computational Linguistics',
#    'HLT-NAACL 2010',
#    'SSST@HLT-NAACL']}]

# %%
manual_venues = []
success_fixed = {}
for row in checked_aliases:
    venues = row["venue"]
    if "name" in row:
        for v in venues:
            success_fixed[v] = {"name": row["name"]}
    vinfo = None
    for v in venues:
        v = clean_venue_name(v)
        if v in cleaned_name_to_info:
            temp = cleaned_name_to_info[v]
            if type(temp) == dict:
                vinfo = temp
                break
    if vinfo is None:
        print("No verified venue found for {}".format(venues))
        manual_venues.append(venues)
        continue
    for v in venues:
        success_fixed[v] = vinfo
# Out:
# No verified venue found for ['Journal of Applied Econometrics', 'journal applied econometrics']
# No verified venue found for ['econometrics journal', 'Journal of Econometrics', 'The Econometrics Journal', 'journal econometrics']
# No verified venue found for ['springer mathematics statistic', 'Springer Proceedings in Mathematics &amp; Statistics']
# No verified venue found for ['international symposium industrial electronics', '2012 IEEE International Symposium on Industrial Electronics', '2009 IEEE International Symposium on Industrial Electronics']
# No verified venue found for ['Journal of Geophysical Research: Solid Earth', 'Journal of Geophysical Research']
# No verified venue found for ['Journal of the Royal Statistical Society Series C: Applied Statistics', 'journal royal statistical society series b']
# No verified venue found for ['Computer-Aided Design', 'computer aided design application']
# No verified venue found for ['european physical journal c', 'european physical journal', 'The European Physical Journal E : Soft matter', 'The European Physical Journal C', 'european physical journal e']
# No verified venue found for ['American Journal of Physics', 'journal applied physic', 'journal physic', 'american journal physic', 'Journal of Applied Physics', 'Journal of Physics: Materials', 'New Journal of Physics', 'Journal of Physics: Complexity', 'new journal physic']
# No verified venue found for ['Philosophical transactions of the Royal Society of London', 'philosophical transaction royal society b']
# No verified venue found for ['journal royal statistical society series c', 'Journal of the Royal Statistical Society Series B: Statistical Methodology']
# No verified venue found for ['Mathematical Geosciences', 'encyclopedia mathematical geosciences']
# No verified venue found for ['Computer-aided Design and Applications', 'computer aided design']
# No verified venue found for ['annals mathematical statistic', 'Annals of Mathematical Statistics']
# No verified venue found for ['Springer proceedings in mathematics & statistics', 'springer mathematics andamp ; statistic']
# No verified venue found for ['2006 International Conference on Intelligent Information Hiding and Multimedia', 'international conference intelligent information hiding multimedia signal processing']
# No verified venue found for ['international journal human resource management', 'Human Resource Management Journal']
# No verified venue found for ['International Journal of Human Resource Management', 'human resource management journal']
# No verified venue found for ['oxford university press ebooks', 'Cambridge University Press eBooks']
# No verified venue found for ['Performance evaluation (Print)', 'performance evaluation review']
# No verified venue found for ['2021 IEEE International Conference on Communications Workshops (ICC Workshops)', 'ieee international conference communication', 'international conference communication']
# No verified venue found for ['transportation research part b', 'Transportation Research Part A: Policy and Practice', 'Transportation Research Part C: Emerging Technologies']
# No verified venue found for ['ISPRS Annals of the Photogrammetry, Remote Sensing and Spatial Information Sciences', 'isprs journal photogrammetry remote sensing']
# No verified venue found for ['Journal of Banking and Finance', 'Journal of Financial Economics', 'journal finance']
# No verified venue found for ['mathematical geosciences', 'Encyclopedia of Mathematical Geosciences']
# No verified venue found for ['performance evaluation', 'Performance evaluation review']
# No verified venue found for ['ieee international conference data mining', '2017 IEEE International Conference on Data Mining Workshops (ICDMW)', '2016 IEEE 16th International Conference on Data Mining Workshops (ICDMW)']
# No verified venue found for ['annual hawaii international conference system science', '1994 Proceedings of the Twenty-Seventh Hawaii International Conference on System Sciences', 'Proceedings of the Thirty-First Hawaii International Conference on System Sciences']
# No verified venue found for ['moon planet', 'Moon and the planets']
# No verified venue found for ['earth moon planet', 'Earth, Moon, and Planets']
# No verified venue found for ['annual meeting ieee industry application society', 'ieee industry application society annual meeting', 'Conference Record of the 1988 IEEE Industry Applications Society Annual Meeting']
# No verified venue found for ['transportation research part', 'Transportation Research Part B: Methodological', 'transportation research part c']
# No verified venue found for ['2009 IEEE International Conference on Intelligent Computing and Intelligent Systems', 'international ieee conference intelligent system']
# No verified venue found for ['2013 IEEE CONFERENCE ON INFORMATION AND COMMUNICATION TECHNOLOGIES', 'ieee international conference computer information technology']
# No verified venue found for ['Philosophical Transactions of the Royal Society B: Biological Sciences', 'philosophical transaction royal society london']
# No verified venue found for ['journal geophysical research', 'Geophysical Journal International']
# No verified venue found for ['Journal of Applied Meteorology and Climatology', 'journal applied meteorology']
# No verified venue found for ['annals applied probability', 'Annals of Probability']
# No verified venue found for ['Journal of Combinatorial Theory, Series B', 'journal combinatorial theory series']
# No verified venue found for ['Proceedings of the 2006 Winter Simulation Conference', 'Proceedings of the 2010 Winter Simulation Conference']
# No verified venue found for ['2009 17th Euromicro International Conference on Parallel, Distributed and Network-based Processing', '2014 22nd Euromicro International Conference on Parallel, Distributed, and Network-Based Processing']
# No verified venue found for ['2012 IEEE International Symposium on Industrial Electronics', '2009 IEEE International Symposium on Industrial Electronics', 'International Symposium on Industrial Electronics']
# No verified venue found for ['Journal of magnetic resonullce', 'Journal of magnetic resonullce (San Diego, Calif. 1997 : Print)']
# No verified venue found for ['2017 25th Mediterranean Conference on Control and Automation (MED)', '2020 28th Mediterranean Conference on Control and Automation (MED)']
# No verified venue found for ['WIREs Data. Mining. Knowl. Discov.', 'WIREs Data Mining Knowl. Discov.']
# No verified venue found for ['Structural Equation Modeling: A Multidisciplinary Journal', 'Structural equation modeling : a multidisciplinary journal']
# No verified venue found for ["LFP '84", "LFP '92", "LFP '86"]
# No verified venue found for ['ML/OCAML', 'ML/OCaml']
# No verified venue found for ['2012 IEEE 12th International Working Conference on Source Code Analysis and Manipulation', '2011 IEEE 11th International Working Conference on Source Code Analysis and Manipulation', '2009 Ninth IEEE International Working Conference on Source Code Analysis and Manipulation']
# No verified venue found for ['2015 IEEE Security and Privacy Workshops', '2017 IEEE Security and Privacy Workshops (SPW)', '2018 IEEE Security and Privacy Workshops (SPW)']
# No verified venue found for ['2010 IEEE/IFIP International Conference on Embedded and Ubiquitous Computing', '2008 IEEE/IFIP International Conference on Embedded and Ubiquitous Computing']
# No verified venue found for ['2011 IEEE International Conference on Industrial Technology', '2006 IEEE International Conference on Industrial Technology']
# No verified venue found for ["SCG '95", "SCG '01", "SCG '94", "SCG '87", "SCG '03", "SCG '04", "SCG '90", "SCG '88", "SCG '02"]
# No verified venue found for ['Journal of magnetic resonance', 'Journal of magnetic resonance (San Diego, Calif. 1997 : Print)']

# %%
clean_venue_name("International Symposium on Industrial Electronics")
# Out:
# 'international symposium industrial electronics'

# %%
cleaned_name_to_info["international symposium industrial electronics"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 cleaned_name_to_info["international symposium industrial electronics"]
#
# KeyError: 'international symposium industrial electronics'

# %%
success_fixed["2009 IEEE 31st International Conference on Software Engineering"]
# Out:
# {'Index': 103,
#  'raw_name': 'International Conference on Software Engineering',
#  'id': 'a36dc29e-4ea1-4567-b0fe-1c06daf8bee8',
#  'name': 'International Conference on Software Engineering',
#  'type': 'conference',
#  'alternate_names': ['Int Conf Softw Eng', 'ICSE'],
#  'issn': nan,
#  'url': 'http://www.icse-conferences.org/',
#  'alternate_urls': nan,
#  'alternate_issns': nan,
#  'clean_name': 'international conference software engineering'}

# %%
openalex_venues = [k for k, v in venue_info.items() if type(v) == str]
print("Found {} OpenAlex venues".format(len(openalex_venues)))
# Out:
# Found 1364 OpenAlex venues

# %%
fixed_at_alias = {}
for venue in openalex_venues:
    if venue in fixed_at_alias:
        continue
    if "@" in venue:
        parts = venue.split("@")
        for part in parts:
            if part in venue_info:
                fixed_at_alias[venue] = venue_info[part]
                break
openalex_venues = [k for k in openalex_venues if k not in fixed_at_alias]
print(
    "Found {} fixed aliases; {} to go".format(len(fixed_at_alias), len(openalex_venues))
)
# Out:
# Found 37 fixed aliases; 1327 to go

# %%
final_venues = {}
i = 0
for venue, info in venue_info.items():
    if type(info) == dict:
        final_venues[venue] = info
        continue
    cleaned_name = clean_venue_name(venue)
    if cleaned_name in cleaned_name_to_info:
        final_venues[venue] = cleaned_name_to_info[cleaned_name]
    elif venue in success_fixed:
        final_venues[venue] = success_fixed[venue]
    elif cleaned_name in success_fixed:
        final_venues[venue] = success_fixed[cleaned_name]
    elif venue in fixed_at_alias:
        final_venues[venue] = fixed_at_alias[venue]
        i += 1
    else:
        final_venues[venue] = venue
len(final_venues), i
# Out:
# (7279, 37)

# %%
with open("venues.json", "w") as f:
    json.dump(final_venues, f, indent=2, default=str)

# %%
def trim_venue_name(venue: str):
    trim_stop_words = ["th", "st", "nd", "rd", "volume"]
    venue = number_parser.parse(venue)
    venue = (
        venue.replace(".", "")
        .replace("&", "and")
        .replace("'", "")
        .replace("/", " ")
        .replace("-", " ")
        .replace(",", "")
        .lower()
    )
    venue = re.sub("\\d+", "", venue)
    venue = re.sub("\\(.+?\\)", "", venue)
    tokens = nltk.word_tokenize(venue)
    return " ".join([t for t in tokens if t not in trim_stop_words])

# %%
with open("venues.json", "r") as f:
    final_venues = json.load(f)

not_info_venues = {}
for venue, info in final_venues.items():
    if type(info) == dict:
        continue
    trimmed_name = trim_venue_name(venue)
    if trimmed_name not in not_info_venues:
        not_info_venues[trimmed_name] = set()
    not_info_venues[trimmed_name].add(venue)
    if "Symposium on Symbolic and Numeric Algorithms for Scientific Computing".lower() in venue.lower():
        print(trimmed_name, not_info_venues[trimmed_name])
not_info_venues = {k: list(v) for k, v in not_info_venues.items() if len(v) > 1}
with open("not_info_venues.json", "w") as f:
    json.dump(not_info_venues, f, indent=2)

# %%
with open("venues.json", "r") as f:
    final_venues = json.load(f)

for venue, info in final_venues.items():
    if type(info) == dict:
        continue
    norm_name = trim_venue_name(venue)
    final_venues[venue] = norm_name.capitalize()

with open("venues.json", "w") as f:
    json.dump(final_venues, f, indent=2)

# %%
final_venues["2006 IEEE Symposium on Interactive Ray Tracing"]
# Out:
# 'Ieee symposium on interactive ray tracing'
